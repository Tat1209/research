# %%
import sys
from pathlib import Path

import torch
from torchvision.transforms import v2 as transforms

this_path = Path(__file__) if '__file__' in globals() else Path("<undefined>.ipynb").resolve()
work_path = next((p for p in this_path.parents if p.name == "research"), None)
tools_path = work_path / Path("../torch-tools")
sys.path.append(str(tools_path))

ee_tools_path_p = work_path / Path("ee")
sys.path.append(str(ee_tools_path_p))

from trainer import Trainer, Network
from datasets import fetch_handler

# from models.resnet_cifar import resnet18 as mine
# from resnet_ku import ResNet18 as ku
# from resnet_we import resnet18 as we

from torchvision.models import mobilenet_v2 as tv
from models.mobilenet_v2_cifar import mobilenet_v2 as mine

from ee_tools.models.mobilenet_v2_ee import mobilenet_v2 as ee

# %%
network = Network(tv(num_classes=100, width_mult=0.5))
net_name = "tv05"

p = Path(this_path.parent / f"{net_name}.txt")
ti = network.torchinfo(input_size=(1, 3, 32, 32))
p.write_text(str(ti))
# Out:
# 18897

# %%
network = Network(ee(num_classes=100, ee_div=32))
net_name = "ee"

p = Path(this_path.parent / f"{net_name}.txt")
ti = network.torchinfo(input_size=(1, 3, 32, 32))
p.write_text(str(ti))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[8], line 1
# ----> 1 network = Network(ee(num_classes=100, ee_div=32))
#       2 net_name = "ee"
#
# File ~/research/.env/lib/python3.13/site-packages/torchvision/models/_utils.py:142, in kwonly_to_pos_or_kw.<locals>.wrapper(*args, **kwargs)
#     140     kwargs.update(keyword_only_kwargs)
# --> 142 return fn(*args, **kwargs)
#
# File ~/research/.env/lib/python3.13/site-packages/torchvision/models/_utils.py:228, in handle_legacy_interface.<locals>.outer_wrapper.<locals>.inner_wrapper(*args, **kwargs)
#     226     kwargs[weights_param] = default_weights_arg
# --> 228 return builder(*args, **kwargs)
#
# File ~/research/ee/ee_tools/models/mobilenet_v2_ee.py:278, in mobilenet_v2(weights, progress, **kwargs)
#     276     _ovewrite_named_param(kwargs, "num_classes", len(weights.meta["categories"]))
# --> 278 model = MobileNetV2(**kwargs)
#     280 if weights is not None:
#
# File ~/research/ee/ee_tools/models/mobilenet_v2_ee.py:153, in MobileNetV2.__init__(self, num_classes, width_mult, inverted_residual_setting, round_nearest, block, norm_layer, dropout, ee_div, merge_mode, ee_init)
#     151 # building last several layers
#     152 features.append(
# --> 153     Conv2dNormActivation(
#     154         input_channel * ee_div, self.last_channel * ee_div, kernel_size=1, groups=ee_div**2, norm_layer=norm_layer, activation_layer=nn.ReLU6
#     155     )
#     156 )
#     157 # make it nn.Sequential
#
# File ~/research/.env/lib/python3.13/site-packages/torchvision/ops/misc.py:159, in Conv2dNormActivation.__init__(self, in_channels, out_channels, kernel_size, stride, padding, groups, norm_layer, activation_layer, dilation, inplace, bias)
#     144 def __init__(
#     145     self,
#     146     in_channels: int,
#    (...)    156     bias: Optional[bool] = None,
#     157 ) -> None:
# --> 159     super().__init__(
#     160         in_channels,
#     161         out_channels,
#     162         kernel_size,
#     163         stride,
#     164         padding,
#     165         groups,
#     166         norm_layer,
#     167         activation_layer,
#     168         dilation,
#     169         inplace,
#     170         bias,
#     171         torch.nn.Conv2d,
#     172     )
#
# File ~/research/.env/lib/python3.13/site-packages/torchvision/ops/misc.py:97, in ConvNormActivation.__init__(self, in_channels, out_channels, kernel_size, stride, padding, groups, norm_layer, activation_layer, dilation, inplace, bias, conv_layer)
#      94     bias = norm_layer is None
#      96 layers = [
# ---> 97     conv_layer(
#      98         in_channels,
#      99         out_channels,
#     100         kernel_size,
#     101         stride,
#     102         padding,
#     103         dilation=dilation,
#     104         groups=groups,
#     105         bias=bias,
#     106     )
#     107 ]
#     109 if norm_layer is not None:
#
# File ~/research/.env/lib/python3.13/site-packages/torch/nn/modules/conv.py:521, in Conv2d.__init__(self, in_channels, out_channels, kernel_size, stride, padding, dilation, groups, bias, padding_mode, device, dtype)
#     520 dilation_ = _pair(dilation)
# --> 521 super().__init__(
#     522     in_channels,
#     523     out_channels,
#     524     kernel_size_,
#     525     stride_,
#     526     padding_,
#     527     dilation_,
#     528     False,
#     529     _pair(0),
#     530     groups,
#     531     bias,
#     532     padding_mode,
#     533     **factory_kwargs,
#     534 )
#
# File ~/research/.env/lib/python3.13/site-packages/torch/nn/modules/conv.py:166, in _ConvNd.__init__(self, in_channels, out_channels, kernel_size, stride, padding, dilation, transposed, output_padding, groups, bias, padding_mode, device, dtype)
#     164 else:
#     165     self.weight = Parameter(
# --> 166         torch.empty(
#     167             (out_channels, in_channels // groups, *kernel_size),
#     168             **factory_kwargs,
#     169         )
#     170     )
#     171 if bias:
#
# RuntimeError: [enforce fail at alloc_cpu.cpp:119] err == 0. DefaultCPUAllocator: can't allocate memory: you tried to allocate 1717986918400 bytes. Error code 12 (Cannot allocate memory)
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/research/.env/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3693, in InteractiveShell.run_code(self, code_obj, result, async_)
#    3691 except:
#    3692     if result is not None:
# -> 3693         result.error_in_exec = sys.exc_info()[1]
#    3694     self.showtraceback(running_compiled_code=True)
#    3695 else:
#
# KeyboardInterrupt:
