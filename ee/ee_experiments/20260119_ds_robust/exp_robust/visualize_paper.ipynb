# %%
import sys
from pathlib import Path

import polars as pl
import numpy as np
import matplotlib.pyplot as plt
from cycler import cycler
import seaborn as sns

this_path = Path(__file__) if '__file__' in globals() else Path("<unknown>.ipynb").resolve()
work_path = next((p for p in this_path.parents if p.name == "research"), None)
tools_path = work_path / Path("../torch-tools")
sys.path.append(str(tools_path))

from exp_manager import cat_results
import pl_utils

# %%
pl_utils.Config()

p_path = this_path.parent
print(p_path)

paths = [p_path]
# paths = [p_path / "exp_*"]

df_base = cat_results(paths)
df_base = df_base.filter(pl.col("epochs") == pl.col("epoch").list.last())

# df_base.pipe(pl_utils.resolve_nested).write_csv(p_path / "df_base.csv")

print(df_base.columns)
print(df_base)
# Out:
# /newssd/projects/tat/research/ee/ee_experiments/20260119_ds_robust/exp_robust
# ['exp_name', 'run_id', 'model_arc', 'train_dataset', 'val_dataset', 'num_classes', 'train_trans', 'val_trans', 'train_ndata', 'val_ndata', 'ipc', 'ipc_is_balanced', 'ipc_info', 'epochs', 'max_lr', 'wd', 'batch_size', 'iters/epoch', 'iters', 'processed_ndata', 'div', 'ensembles', 'scale_ch', 'refiner', 'num_params', 'criterion', 'optimizer', 'scheduler', 'step', 'epoch', 'lr', 'train_loss', 'train_acc', 'val_loss', 'val_acc', 'dur_total_core', 'dur_total_core_fmt', 'dur_train_core', 'dur_train_core_fmt', 'dur_total', 'dur_total_fmt', 'dur_train', 'dur_train_fmt', 'progress']
# shape: (545, 44)
# ┌────────────┬───────────────────────────┬───────────┬──────────────────┬─────────────────┬─────────────┬───────────────────────────┬───────────────────────────┬─────────────┬───────────┬───────┬─────────────────┬───────────────────────────┬────────┬─────────┬──────┬────────────┬─────────────┬───────┬─────────────────┬─────┬───────────┬──────────┬───────────────────────────┬────────────┬──────────────────┬───────────┬───────────────────┬─────────────────┬─────────────────┬───────────────────────────┬───────────────────────────┬───────────────────────────┬──────────────────────────┬──────────────────────────┬───────────────────────────┬───────────────────────────┬───────────────────────────┬───────────────────────────┬───────────────────────────┬───────────────────────────┬───────────────────────────┬───────────────────────────┬───────────────────────────┐
# │ exp_name   ┆ run_id                    ┆ model_arc ┆ train_dataset    ┆ val_dataset     ┆ num_classes ┆ train_trans               ┆ val_trans                 ┆ train_ndata ┆ val_ndata ┆   ipc ┆ ipc_is_balanced ┆ ipc_info                  ┆ epochs ┆  max_lr ┆   wd ┆ batch_size ┆ iters/epoch ┆ iters ┆ processed_ndata ┆ div ┆ ensembles ┆ scale_ch ┆ refiner                   ┆ num_params ┆ criterion        ┆ optimizer ┆ scheduler         ┆ step            ┆ epoch           ┆ lr                        ┆ train_loss                ┆ train_acc                 ┆ val_loss                 ┆ val_acc                  ┆ dur_total_core            ┆ dur_total_core_fmt        ┆ dur_train_core            ┆ dur_train_core_fmt        ┆ dur_total                 ┆ dur_total_fmt             ┆ dur_train                 ┆ dur_train_fmt             ┆ progress                  │
# │ ---        ┆ ---                       ┆ ---       ┆ ---              ┆ ---             ┆         --- ┆ ---                       ┆ ---                       ┆         --- ┆       --- ┆   --- ┆ ---             ┆ ---                       ┆    --- ┆     --- ┆  --- ┆        --- ┆         --- ┆   --- ┆             --- ┆ --- ┆       --- ┆      --- ┆ ---                       ┆        --- ┆ ---              ┆ ---       ┆ ---               ┆ ---             ┆ ---             ┆ ---                       ┆ ---                       ┆ ---                       ┆ ---                      ┆ ---                      ┆ ---                       ┆ ---                       ┆ ---                       ┆ ---                       ┆ ---                       ┆ ---                       ┆ ---                       ┆ ---                       ┆ ---                       │
# │ str        ┆ str                       ┆ str       ┆ str              ┆ str             ┆         i64 ┆ str                       ┆ str                       ┆         i64 ┆       i64 ┆   f64 ┆ bool            ┆ struct[7]                 ┆    i64 ┆     f64 ┆  f64 ┆        i64 ┆         i64 ┆   i64 ┆             i64 ┆ i64 ┆       i64 ┆      f64 ┆ str                       ┆        i64 ┆ str              ┆ str       ┆ str               ┆ list[i64]       ┆ list[i64]       ┆ list[f64]                 ┆ list[f64]                 ┆ list[f64]                 ┆ list[f64]                ┆ list[f64]                ┆ list[f64]                 ┆ list[str]                 ┆ list[f64]                 ┆ list[str]                 ┆ list[f64]                 ┆ list[str]                 ┆ list[f64]                 ┆ list[str]                 ┆ list[str]                 │
# ╞════════════╪═══════════════════════════╪═══════════╪══════════════════╪═════════════════╪═════════════╪═══════════════════════════╪═══════════════════════════╪═════════════╪═══════════╪═══════╪═════════════════╪═══════════════════════════╪════════╪═════════╪══════╪════════════╪═════════════╪═══════╪═════════════════╪═════╪═══════════╪══════════╪═══════════════════════════╪════════════╪══════════════════╪═══════════╪═══════════════════╪═════════════════╪═════════════════╪═══════════════════════════╪═══════════════════════════╪═══════════════════════════╪══════════════════════════╪══════════════════════════╪═══════════════════════════╪═══════════════════════════╪═══════════════════════════╪═══════════════════════════╪═══════════════════════════╪═══════════════════════════╪═══════════════════════════╪═══════════════════════════╪═══════════════════════════╡
# │ exp_robust ┆ run_2026-01-24_17-02-14_… ┆ resnet18  ┆ stl10_train      ┆ stl10_val       ┆          10 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆        5000 ┆      8000 ┆ 500.0 ┆ true            ┆ {true,500,500,500,500.0,… ┆    400 ┆   0.005 ┆ 0.05 ┆        128 ┆          40 ┆ 16000 ┆         2000000 ┆   2 ┆         4 ┆      0.5 ┆ Base._remove_downsample(… ┆   11190440 ┆ CrossEntropyLoss ┆ AdamW     ┆ CosineAnnealingLR ┆ [1, 2, … 400]   ┆ [1, 2, … 400]   ┆ [0.005, 0.005, … 7.7106e… ┆ [1.887471, 1.661017, … 0… ┆ [0.2802, 0.3572, … 1.0]   ┆ [null, null, … 1.135933] ┆ [null, null, … 0.758]    ┆ [136.593315, 138.505829,… ┆ ["2.3m", "2.3m", … "16.3… ┆ [136.593477, 138.506213,… ┆ ["2.3m", "2.3m", … "14.8… ┆ [136.725551, 138.923971,… ┆ ["2.3m", "2.3m", … "20.0… ┆ [136.725559, 138.923982,… ┆ ["2.3m", "2.3m", … "15.7… ┆ ["0.2%", "0.5%", … "100.… │
# │ exp_robust ┆ run_2026-01-24_17-02-14_… ┆ resnet18  ┆ stl10_train      ┆ stl10_val       ┆          10 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆        5000 ┆      8000 ┆ 500.0 ┆ true            ┆ {true,500,500,500,500.0,… ┆    400 ┆   0.005 ┆ 0.05 ┆        128 ┆          40 ┆ 16000 ┆         2000000 ┆   1 ┆         1 ┆      1.0 ┆ Base._remove_downsample(… ┆   11173962 ┆ CrossEntropyLoss ┆ AdamW     ┆ CosineAnnealingLR ┆ [1, 2, … 400]   ┆ [1, 2, … 400]   ┆ [0.005, 0.005, … 7.7106e… ┆ [2.146966, 1.85678, … 0.… ┆ [0.218, 0.2754, … 1.0]    ┆ [null, null, … 1.260883] ┆ [null, null, … 0.769625] ┆ [145.860447, 146.708067,… ┆ ["2.4m", "2.4m", … "9.0m… ┆ [145.860692, 146.708538,… ┆ ["2.4m", "2.4m", … "7.6m… ┆ [146.838993, 149.030534,… ┆ ["2.4m", "2.5m", … "19.3… ┆ [146.839001, 149.030545,… ┆ ["2.4m", "2.5m", … "14.6… ┆ ["0.2%", "0.5%", … "100.… │
# │ exp_robust ┆ run_2026-01-24_17-02-14_… ┆ resnet18  ┆ stl10_train      ┆ stl10_val       ┆          10 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆        5000 ┆      8000 ┆ 500.0 ┆ true            ┆ {true,500,500,500,500.0,… ┆    400 ┆   0.005 ┆ 0.05 ┆        128 ┆          40 ┆ 16000 ┆         2000000 ┆   4 ┆        16 ┆     0.25 ┆ Base._remove_downsample(… ┆   11223456 ┆ CrossEntropyLoss ┆ AdamW     ┆ CosineAnnealingLR ┆ [1, 2, … 400]   ┆ [1, 2, … 400]   ┆ [0.005, 0.005, … 7.7106e… ┆ [1.771783, 1.582822, … 0… ┆ [0.2984, 0.4018, … 0.999… ┆ [null, null, … 0.971647] ┆ [null, null, … 0.767625] ┆ [144.895183, 148.627856,… ┆ ["2.4m", "2.5m", … "30.1… ┆ [144.895499, 148.628377,… ┆ ["2.4m", "2.5m", … "27.3… ┆ [145.027257, 148.926904,… ┆ ["2.4m", "2.5m", … "32.8… ┆ [145.027264, 148.926919,… ┆ ["2.4m", "2.5m", … "28.2… ┆ ["0.2%", "0.5%", … "100.… │
# │ exp_robust ┆ run_2026-01-24_17-02-15_… ┆ resnet18  ┆ stl10_train      ┆ stl10_val       ┆          10 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆        5000 ┆      8000 ┆ 500.0 ┆ true            ┆ {true,500,500,500,500.0,… ┆    400 ┆   0.005 ┆ 0.05 ┆        128 ┆          40 ┆ 16000 ┆         2000000 ┆   8 ┆        64 ┆    0.125 ┆ Base._remove_downsample(… ┆   11289728 ┆ CrossEntropyLoss ┆ AdamW     ┆ CosineAnnealingLR ┆ [1, 2, … 400]   ┆ [1, 2, … 400]   ┆ [0.005, 0.005, … 7.7106e… ┆ [1.718529, 1.41804, … 0.… ┆ [0.351, 0.479, … 0.9994]  ┆ [null, null, … 0.984516] ┆ [null, null, … 0.75125]  ┆ [152.715196, 159.843969,… ┆ ["2.5m", "2.7m", … "55.9… ┆ [152.715459, 159.844466,… ┆ ["2.5m", "2.7m", … "50.3… ┆ [152.847806, 160.144653,… ┆ ["2.5m", "2.7m", … "57.2… ┆ [152.847813, 160.144665,… ┆ ["2.5m", "2.7m", … "51.2… ┆ ["0.2%", "0.5%", … "100.… │
# │ exp_robust ┆ run_2026-01-24_17-02-15_… ┆ resnet18  ┆ stl10_train      ┆ stl10_val       ┆          10 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆        5000 ┆      8000 ┆ 500.0 ┆ true            ┆ {true,500,500,500,500.0,… ┆    400 ┆   0.005 ┆ 0.05 ┆        128 ┆          40 ┆ 16000 ┆         2000000 ┆  16 ┆       256 ┆   0.0625 ┆ Base._remove_downsample(… ┆   11423232 ┆ CrossEntropyLoss ┆ AdamW     ┆ CosineAnnealingLR ┆ [1, 2, … 400]   ┆ [1, 2, … 400]   ┆ [0.005, 0.005, … 7.7106e… ┆ [1.763232, 1.393752, … 0… ┆ [0.3548, 0.504, … 0.9998… ┆ [null, null, … 0.819959] ┆ [null, null, … 0.7675]   ┆ [170.109742, 185.325968,… ┆ ["2.8m", "3.1m", … "2.0h… ┆ [170.110055, 185.326616,… ┆ ["2.8m", "3.1m", … "1.8h… ┆ [170.249082, 185.599305,… ┆ ["2.8m", "3.1m", … "2.0h… ┆ [170.249103, 185.599333,… ┆ ["2.8m", "3.1m", … "1.8h… ┆ ["0.2%", "0.5%", … "100.… │
# │ …          ┆ …                         ┆ …         ┆ …                ┆ …               ┆           … ┆ …                         ┆ …                         ┆           … ┆         … ┆     … ┆ …               ┆ …                         ┆      … ┆       … ┆    … ┆          … ┆           … ┆     … ┆               … ┆   … ┆         … ┆        … ┆ …                         ┆          … ┆ …                ┆ …         ┆ …                 ┆ …               ┆ …               ┆ …                         ┆ …                         ┆ …                         ┆ …                        ┆ …                        ┆ …                         ┆ …                         ┆ …                         ┆ …                         ┆ …                         ┆ …                         ┆ …                         ┆ …                         ┆ …                         │
# │ exp_robust ┆ run_2026-02-06_21-44-57_… ┆ resnet18  ┆ flowers102_train ┆ flowers102_test ┆         102 ┆ [ToImage(), GrayToRGB(),… ┆ [ToImage(), GrayToRGB(),… ┆         102 ┆      6149 ┆   1.0 ┆ true            ┆ {true,1,1,1,1.0,0.0,1.0}  ┆  19607 ┆ 0.00125 ┆ 0.05 ┆         32 ┆           4 ┆ 78428 ┆         1999914 ┆   4 ┆        16 ┆     0.25 ┆ Base._ee_convert(ensembl… ┆   11444064 ┆ CrossEntropyLoss ┆ AdamW     ┆ CosineAnnealingLR ┆ [1, 2, … 19607] ┆ [1, 2, … 19607] ┆ [0.00125, 0.00125, … 8.0… ┆ [4.748808, 4.400216, … 0… ┆ [0.009804, 0.04902, … 1.… ┆ [null, null, … 7.484201] ┆ [null, null, … 0.194991] ┆ [25.188513, 25.547575, …… ┆ ["25.2s", "25.5s", … "1.… ┆ [25.188553, 25.547634, …… ┆ ["25.2s", "25.5s", … "55… ┆ [25.314824, 25.811186, …… ┆ ["25.3s", "25.8s", … "1.… ┆ [25.314831, 25.811195, …… ┆ ["25.3s", "25.8s", … "1.… ┆ ["0.0%", "0.0%", … "100.… │
# │ exp_robust ┆ run_2026-02-06_21-45-07_… ┆ resnet18  ┆ flowers102_train ┆ flowers102_test ┆         102 ┆ [ToImage(), GrayToRGB(),… ┆ [ToImage(), GrayToRGB(),… ┆         102 ┆      6149 ┆   1.0 ┆ true            ┆ {true,1,1,1,1.0,0.0,1.0}  ┆  19607 ┆ 0.00125 ┆ 0.05 ┆         32 ┆           4 ┆ 78428 ┆         1999914 ┆   8 ┆        64 ┆    0.125 ┆ Base._ee_convert(ensembl… ┆   11733888 ┆ CrossEntropyLoss ┆ AdamW     ┆ CosineAnnealingLR ┆ [1, 2, … 19607] ┆ [1, 2, … 19607] ┆ [0.00125, 0.00125, … 8.0… ┆ [4.677502, 4.510653, … 0… ┆ [0.0, 0.068627, … 1.0]    ┆ [null, null, … 6.486714] ┆ [null, null, … 0.204586] ┆ [18.750264, 19.368906, …… ┆ ["18.8s", "19.4s", … "2.… ┆ [18.750308, 19.368968, …… ┆ ["18.8s", "19.4s", … "2.… ┆ [18.882673, 19.659263, …… ┆ ["18.9s", "19.7s", … "3.… ┆ [18.88268, 19.659273, … … ┆ ["18.9s", "19.7s", … "3.… ┆ ["0.0%", "0.0%", … "100.… │
# │ exp_robust ┆ run_2026-02-06_22-43-40_… ┆ resnet18  ┆ flowers102_train ┆ flowers102_test ┆         102 ┆ [ToImage(), GrayToRGB(),… ┆ [ToImage(), GrayToRGB(),… ┆         102 ┆      6149 ┆   1.0 ┆ true            ┆ {true,1,1,1,1.0,0.0,1.0}  ┆  19607 ┆ 0.00125 ┆ 0.05 ┆         32 ┆           4 ┆ 78428 ┆         1999914 ┆  16 ┆       256 ┆   0.0625 ┆ Base._ee_convert(ensembl… ┆   12323328 ┆ CrossEntropyLoss ┆ AdamW     ┆ CosineAnnealingLR ┆ [1, 2, … 19607] ┆ [1, 2, … 19607] ┆ [0.00125, 0.00125, … 8.0… ┆ [4.652682, 4.589757, … 0… ┆ [0.009804, 0.107843, … 1… ┆ [null, null, … 5.660852] ┆ [null, null, … 0.212718] ┆ [30.475422, 31.452628, …… ┆ ["30.5s", "31.5s", … "5.… ┆ [30.475459, 31.452677, …… ┆ ["30.5s", "31.5s", … "4.… ┆ [30.597687, 31.720241, …… ┆ ["30.6s", "31.7s", … "6.… ┆ [30.597694, 31.720251, …… ┆ ["30.6s", "31.7s", … "5.… ┆ ["0.0%", "0.0%", … "100.… │
# │ exp_robust ┆ run_2026-02-06_23-07-27_… ┆ resnet18  ┆ flowers102_train ┆ flowers102_test ┆         102 ┆ [ToImage(), GrayToRGB(),… ┆ [ToImage(), GrayToRGB(),… ┆         102 ┆      6149 ┆   1.0 ┆ true            ┆ {true,1,1,1,1.0,0.0,1.0}  ┆  19607 ┆ 0.00125 ┆ 0.05 ┆         32 ┆           4 ┆ 78428 ┆         1999914 ┆  32 ┆      1024 ┆  0.03125 ┆ Base._ee_convert(ensembl… ┆   13541376 ┆ CrossEntropyLoss ┆ AdamW     ┆ CosineAnnealingLR ┆ [1, 2, … 19607] ┆ [1, 2, … 19607] ┆ [0.00125, 0.00125, … 8.0… ┆ [4.639889, 4.610944, … 0… ┆ [0.009804, 0.04902, … 1.… ┆ [null, null, … 5.042908] ┆ [null, null, … 0.218247] ┆ [89.128427, 91.511202, …… ┆ ["1.5m", "1.5m", … "13.4… ┆ [89.128465, 91.511286, …… ┆ ["1.5m", "1.5m", … "12.1… ┆ [89.240391, 91.769107, …… ┆ ["1.5m", "1.5m", … "14.1… ┆ [89.240397, 91.769118, …… ┆ ["1.5m", "1.5m", … "12.8… ┆ ["0.0%", "0.0%", … "100.… │
# │ exp_robust ┆ run_2026-02-07_18-41-48_… ┆ resnet18  ┆ cifar10_train    ┆ cifar10_test    ┆          10 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆        5000 ┆     10000 ┆ 500.0 ┆ true            ┆ {true,500,500,500,500.0,… ┆    400 ┆   0.005 ┆ 0.05 ┆        128 ┆          40 ┆ 16000 ┆         2000000 ┆  32 ┆      1024 ┆  0.03125 ┆ Base._remove_downsample(… ┆   11694080 ┆ CrossEntropyLoss ┆ AdamW     ┆ CosineAnnealingLR ┆ [1, 2, … 400]   ┆ [1, 2, … 400]   ┆ [0.005, 0.005, … 7.7106e… ┆ [2.011622, 1.614777, … 0… ┆ [0.2898, 0.4196, … 1.0]   ┆ [null, null, … 0.765952] ┆ [null, null, … 0.7627]   ┆ [171.731689, 194.250258,… ┆ ["2.9m", "3.2m", … "2.8h… ┆ [171.73184, 194.250704, … ┆ ["2.9m", "3.2m", … "2.6h… ┆ [171.805256, 194.466786,… ┆ ["2.9m", "3.2m", … "2.8h… ┆ [171.805264, 194.466797,… ┆ ["2.9m", "3.2m", … "2.6h… ┆ ["0.2%", "0.5%", … "100.… │
# └────────────┴───────────────────────────┴───────────┴──────────────────┴─────────────────┴─────────────┴───────────────────────────┴───────────────────────────┴─────────────┴───────────┴───────┴─────────────────┴───────────────────────────┴────────┴─────────┴──────┴────────────┴─────────────┴───────┴─────────────────┴─────┴───────────┴──────────┴───────────────────────────┴────────────┴──────────────────┴───────────┴───────────────────┴─────────────────┴─────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┴──────────────────────────┴──────────────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┘

# %%
df_b = df_base
# df_b = df_b.pipe(pl_utils.add_iter_epoch).pipe(pl_utils.unnest_iter)

# df_b = df_b.filter(pl.col("optimizer") == "SGD")
# df_b = df_b.filter(pl.col("train_ndata").is_in([10000, 5000]))
# df_b = df_b.filter(pl.col("model_arc").str.contains("cifar"))
# df_b = df_b.filter(pl.col("train_dataset").str.contains("svhn"))

df_b = df_b.filter(pl.col("div").is_in([1, 4, 16, 32]))
df_b = df_b.filter(pl.col("ipc").is_in([5, 10, 50, 100, 500]))

# df_b = df_b.filter((pl.col("train_dataset") != "fashion-mnist_train") | (pl.col("ipc").is_in([1, 10, 50, 100, 1000, 5000])))
# df_b = df_b.filter((pl.col("train_dataset") != "tiny-imagenet_train") | (pl.col("ipc").is_in([1, 10, 50, 100, 200, 500])))
# df_b = df_b.filter((pl.col("train_dataset") != "cifar10_train") | (pl.col("ipc").is_in([1, 10, 50, 100, 1000, 5000])))
# # df_b = df_b.filter((pl.col("train_dataset") != "cub200_train") | (pl.col("ipc").is_in([1, 10, 100])))
# # df_b = df_b.filter((pl.col("train_dataset") != "caltech101_labeled") | (pl.col("ipc").is_in([1, 10, 100])))
#
# df_b = df_b.filter(pl.col("train_dataset").is_in(["fashion-mnist_train", "tiny-imagenet_train", "cub200_train", "cifar10_train"]))

ipc_fmt = (
    pl.when(pl.col("ipc").mod(1) == 0)
    .then(pl.col("ipc").cast(pl.Int64).cast(pl.String))
    .otherwise(pl.col("ipc").round(2).cast(pl.String))
)

df_b = df_b.with_columns(
    pl.when(~pl.col("ipc_is_balanced"))
    .then(pl.lit("full"))
    # .then(pl.lit("full\n(") + ipc_fmt + pl.lit(")"))
    .otherwise(ipc_fmt) # balancedの場合もフォーマットを統一して文字列にする必要がある
    .alias("ipc")
)

# df_b = df_b.with_columns(
#     pl.when(~pl.col("ipc_is_balanced"))
#     .then(
#         pl.lit("full\n(") 
#         + pl.col("train_ndata").cast(pl.String) 
#         + pl.lit(" imgs)")  # 単位を追加
#     )
#     .otherwise(ipc_fmt)     # balancedの場合はIPCの数値を整形して表示
#     .alias("ipc")
# )

# red = "$r$"
tra = "Dataset Size"
ipc = "IPC"
va = "test_acc"
red = "r"
# red = "Reduction Factor ($r$)"
ens = "M"
# tra = "Training Dataset Size"
mlr = "Learning Rate (η)"
wd_l = "Weight Decay (λ)"
df_b = df_b.rename({"div": red, "train_ndata": tra, "val_acc": va, "ipc": ipc, "ensembles": ens, "max_lr": mlr, "wd": wd_l})

# %%
df_e = df_b
df_e = df_b.pipe(pl_utils.snapshot)

ext_columns = ["train_dataset"] # この要素ごとにheatmapを表示
# ext_columns = ["train_dataset", "optimizer"] # この要素ごとにheatmapを表示
piv_values = [va]
# piv_values = ["train_acc", "val_acc", "train_loss", "val_loss"]
piv_indices = [red, ens] # 縦軸
piv_on = [ipc] # 横軸
# piv_on = ["train_ndata"] # 横軸
# piv_on = ["epochs", "wd"] # 横軸

sort_str_pos = "first" # 文字列カラム（数値以外）の位置指定: "first" (先頭) または "last" (末尾)

# heatmap
agg = "last"
axis = 0    # None: 正規化なし, 0: 行方向, 1: 列方向

norm = "zscore"  # "minmax", "zscore", None
square_size = 0.75

# graph
graph_size = (4, 3)
ylim = True
x_col = "step"
# x_col = "iter_step"

# %%
import matplotlib.ticker as ticker
import polars as pl
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def format_axis_label(val: float | str) -> str:
    try:
        f_val = float(val)
        if f_val.is_integer():
            return str(int(f_val))
        return f"{f_val:.2f}"
    except (ValueError, TypeError):
        return str(val)

def format_pivot_columns(df: pl.DataFrame, group_cols: list | None = None, non_numeric_position: str = "last") -> pl.DataFrame:
    col_df = pl.DataFrame({"cols": df.columns})
    
    col_df = col_df.with_columns(
        pl.col("cols").cast(pl.Float32, strict=False).alias("numeric")
    )
    
    if non_numeric_position == "first":
        rank_expr = pl.when(pl.col("numeric").is_null()).then(0).otherwise(1)
    else: 
        rank_expr = pl.when(pl.col("numeric").is_null()).then(1).otherwise(0)

    new_columns = (
        col_df
        .with_columns(rank_expr.alias("rank"))
        .sort(["rank", "numeric", "cols"])["cols"]
        .to_list()
    )
    
    df = df.select(new_columns)

    if group_cols:
        if len(group_cols) == 1:
            idx_alias = group_cols[0]
        else:
            idx_alias = f"({', '.join(group_cols)})"
            df = df.with_columns(
                (pl.lit("(") + pl.concat_str([pl.col(c).cast(pl.String) for c in group_cols], separator=", ") + pl.lit(")")).alias(idx_alias)
            )
        
        existing_cols = [c for c in group_cols if c in df.columns]
        if existing_cols:
            df = df.sort(existing_cols, descending=False).select(idx_alias, pl.col(new_columns).exclude(existing_cols))
            
    return df

plt.style.use(['./common.mplstyle'])
plt.rcParams['axes.titleweight'] = 300
plt.rcParams['axes.labelweight'] = 300

ext_columns = ext_columns if isinstance(ext_columns, list) else [ext_columns]
piv_values = piv_values if isinstance(piv_values, list) else [piv_values]
piv_on = piv_on if isinstance(piv_on, list) else [piv_on]

ext_l_df = df_e.select(ext_columns).unique().sort(ext_columns)

for i, ext_row_dict in enumerate(ext_l_df.iter_rows(named=True)):
    try:
        fig, ax = None, None
        for piv_value in piv_values:
            filter_condition = pl.all_horizontal([(pl.col(k) == v) for k, v in ext_row_dict.items()])
            df_ext = df_e.filter(filter_condition)
            
            target_on = piv_on[0]
            if len(piv_on) > 1:
                target_on = f"({', '.join(piv_on)})"
                df_ext = df_ext.with_columns(
                    (pl.lit("(") + pl.concat_str([pl.col(c).cast(pl.String) for c in piv_on], separator=", ") + pl.lit(")")).alias(target_on)
                )

            df_piv = df_ext.pivot(
                values=piv_value, index=piv_indices, on=target_on, sort_columns=True, aggregate_function=agg
            ).pipe(format_pivot_columns, group_cols=piv_indices)
            
            ax_x = df_piv.columns[1:]
            ax_y = df_piv[df_piv.columns[0]]
            data = df_piv.select(ax_x).to_numpy()
            
            title_parts = [f"{k}: {v}" for k, v in ext_row_dict.items()]
            title_str = ", ".join(title_parts)
            
            if np.issubdtype(data.dtype, np.number):
                annot = data.copy()

                if axis is not None:
                    if norm == "minmax":
                        min_vals = np.nanmin(data, axis=axis, keepdims=True)
                        max_vals = np.nanmax(data, axis=axis, keepdims=True)
                        data = (data - min_vals) / (max_vals - min_vals + 1e-8)
                
                    elif norm == "zscore":
                        mean_vals = np.nanmean(data, axis=axis, keepdims=True)
                        std_vals = np.nanstd(data, axis=axis, keepdims=True)
                        data = (data - mean_vals) / (std_vals + 1e-8)

                if piv_value[-4:] == "_acc":
                    annot *= 100
                
                fig, ax = plt.subplots(figsize=(len(ax_x)*square_size, len(ax_y)*square_size))

                hm_kwargs = {
                    "cmap": "Blues",
                    "cbar": False,
                    "fmt": ".2f",
                    "annot_kws": {"size": 12, "fontweight": 500}
                }

                ax = sns.heatmap(data, annot=annot, square=False, **hm_kwargs)
                
                # ax.set_title(ext_row_dict["train_dataset"].split("_")[0])
                # print(ext_row_dict["train_dataset"].split("_")[0])
                # ax.set_title(title_str, fontsize=14)
                ax.set_xlabel(target_on, fontsize=12)
                ax.set_ylabel(ax_y.name, fontsize=12, rotation=90)

                ax.set_xticklabels([format_axis_label(x).replace(", ", ",\n") for x in ax_x], fontsize=12, rotation=0)
                ax.set_yticklabels([format_axis_label(y) for y in ax_y], fontsize=12, rotation=0)
                
                plt.savefig(f'./lim/{ext_row_dict["train_dataset"].split("_")[0]}_hm.svg', bbox_inches="tight")
                # plt.savefig(f'./full/{ext_row_dict["train_dataset"].split("_")[0]}_hm_full.svg', bbox_inches="tight")
                plt.show()
        
            # else:
            #     plt.style.use(['./line.mplstyle'])
            #     df_step = df_ext.pivot(
            #         values=x_col, index=piv_indices, on=target_on, sort_columns=True, aggregate_function=agg
            #     ).pipe(format_pivot_columns, group_cols=piv_indices)
            #
            #     _ax_x = df_step.columns[1:]
            #     step_data = df_step.select(_ax_x).to_numpy()
            #
            #     nrows, ncols = data.shape
            #
            #     if fig is None:
            #         fig, axes = plt.subplots(
            #             nrows, ncols, 
            #             figsize=(ncols * graph_size[0], nrows * graph_size[1]), 
            #             sharex=False, sharey=False, squeeze=False
            #         )
            #
            #     fig.suptitle(title_str, fontsize=16)
            #
            #     for i in range(nrows):
            #         for j in range(ncols):
            #             ax = axes[i, j]
            #
            #             x_data = step_data[i, j]
            #             y_data = data[i, j]
            #
            #             if x_data is not None and y_data is not None:
            #                 filtered_points = [(x, y) for x, y in zip(x_data, y_data) if y is not None and not np.isnan(y)]
            #                 if len(filtered_points) > 1:
            #                     sorted_points = sorted(filtered_points, key=lambda point: point[0])
            #                     x_plot, y_plot = zip(*sorted_points)
            #                     ax.plot(x_plot, y_plot, label=piv_value)
            #
            #             ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: format_axis_label(x)))
            #             ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda y, pos: format_axis_label(y)))
            #
            #             ax.tick_params(axis='both', which='major') 
            #             legend = ax.legend()
            #
            #             if ylim:
            #                 ax.set_ylim([0, 1.005])
            #
            #     for i, row_label in enumerate(ax_y):
            #         axes[i, 0].set_ylabel(row_label, rotation=0, ha='right', va='center', fontsize=10)
            #
            #     for j, col_label in enumerate(ax_x):
            #         axes[-1, j].set_xlabel(col_label, fontsize=10)
            #
            #     fig.supxlabel(target_on, fontsize=12)
            #     fig.supylabel(ax_y.name, fontsize=12)
            #
            #     plt.tight_layout(rect=[0.02, 0.02, 1, 0.98])
    except ValueError as e:
        print(f"Skipping combination {ext_row_dict} due to error: {e}")

plt.show()
