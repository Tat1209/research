# %%
import sys
from pathlib import Path

import polars as pl
import numpy as np
import matplotlib.pyplot as plt
from cycler import cycler
import seaborn as sns

this_path = Path(__file__) if '__file__' in globals() else Path("<unknown>.ipynb").resolve()
work_path = next((p for p in this_path.parents if p.name == "research"), None)
tools_path = work_path / Path("../torch-tools")
sys.path.append(str(tools_path))

from exp_manager import cat_results
import pl_utils

# %%
pl_utils.Config()

p_path = this_path.parent
print(p_path)

# paths = [p_path]
paths = [p_path / "exp_*"]

df_base = cat_results(paths)
# df_base = df_base.filter(pl.col("epochs") == pl.col("epoch").list.last())

# df_base.pipe(pl_utils.resolve_nested).write_csv(p_path / "df_base.csv")

print(df_base.columns)
print(df_base)
# Out:
# /newssd/projects/tat/research/ee/ee_experiments/20260221_all_results/mn_ndata_opt_wd
# ['exp_name', 'run_id', 'model_arc', 'train_dataset', 'val_dataset', 'num_classes', 'train_trans', 'val_trans', 'train_ndata', 'val_ndata', 'epochs', 'max_lr', 'wd', 'batch_size', 'iters/epoch', 'iters', 'target_steps', 'ndata_per_class', 'fils', 'ensembles', 'base_fils', 'num_params', 'criterion', 'optimizer', 'scheduler', 'step', 'epoch', 'lr', 'train_loss', 'train_acc', 'val_loss', 'val_acc', 'param_norm', 'grad_norm', 'param_norm_layer', 'grad_norm_layer', 'g2w_ratio', 'dur_total_core', 'dur_train_core', 'dur_dl_train', 'loss_path', 'acc_path']
# shape: (360, 42)
# ┌──────────────┬────────┬───────────────────────────┬────────────────┬──────────────┬─────────────┬───────────────────────────┬───────────────────────────┬─────────────┬───────────┬────────┬────────┬──────────┬────────────┬─────────────┬───────┬──────────────┬─────────────────┬──────┬───────────┬───────────┬────────────┬──────────────────┬───────────┬───────────────────┬────────────────┬────────────────┬───────────────────────────┬───────────────────────────┬───────────────────────────┬───────────────────────────┬──────────────────────────┬───────────────────────────┬───────────────────────────┬───────────────────────────┬───────────────────────────┬───────────────────────────┬───────────────────────────┬───────────────────────────┬───────────────────────────┬─────────────────┬─────────────────┐
# │ exp_name     ┆ run_id ┆ model_arc                 ┆ train_dataset  ┆ val_dataset  ┆ num_classes ┆ train_trans               ┆ val_trans                 ┆ train_ndata ┆ val_ndata ┆ epochs ┆ max_lr ┆       wd ┆ batch_size ┆ iters/epoch ┆ iters ┆ target_steps ┆ ndata_per_class ┆ fils ┆ ensembles ┆ base_fils ┆ num_params ┆ criterion        ┆ optimizer ┆ scheduler         ┆ step           ┆ epoch          ┆ lr                        ┆ train_loss                ┆ train_acc                 ┆ val_loss                  ┆ val_acc                  ┆ param_norm                ┆ grad_norm                 ┆ param_norm_layer          ┆ grad_norm_layer           ┆ g2w_ratio                 ┆ dur_total_core            ┆ dur_train_core            ┆ dur_dl_train              ┆ loss_path       ┆ acc_path        │
# │ ---          ┆    --- ┆ ---                       ┆ ---            ┆ ---          ┆         --- ┆ ---                       ┆ ---                       ┆         --- ┆       --- ┆    --- ┆    --- ┆      --- ┆        --- ┆         --- ┆   --- ┆          --- ┆             --- ┆  --- ┆       --- ┆       --- ┆        --- ┆ ---              ┆ ---       ┆ ---               ┆ ---            ┆ ---            ┆ ---                       ┆ ---                       ┆ ---                       ┆ ---                       ┆ ---                      ┆ ---                       ┆ ---                       ┆ ---                       ┆ ---                       ┆ ---                       ┆ ---                       ┆ ---                       ┆ ---                       ┆ ---             ┆ ---             │
# │ str          ┆    i64 ┆ str                       ┆ str            ┆ str          ┆         i64 ┆ str                       ┆ str                       ┆         i64 ┆       i64 ┆    i64 ┆    f64 ┆      f64 ┆        i64 ┆         i64 ┆   i64 ┆          i64 ┆             f64 ┆  i64 ┆       i64 ┆       i64 ┆        i64 ┆ str              ┆ str       ┆ str               ┆ list[i64]      ┆ list[i64]      ┆ list[f64]                 ┆ list[f64]                 ┆ list[f64]                 ┆ list[f64]                 ┆ list[f64]                ┆ list[f64]                 ┆ list[f64]                 ┆ list[struct[62]]          ┆ list[struct[62]]          ┆ list[f64]                 ┆ list[f64]                 ┆ list[f64]                 ┆ list[f64]                 ┆ list[list[f64]] ┆ list[list[f64]] │
# ╞══════════════╪════════╪═══════════════════════════╪════════════════╪══════════════╪═════════════╪═══════════════════════════╪═══════════════════════════╪═════════════╪═══════════╪════════╪════════╪══════════╪════════════╪═════════════╪═══════╪══════════════╪═════════════════╪══════╪═══════════╪═══════════╪════════════╪══════════════════╪═══════════╪═══════════════════╪════════════════╪════════════════╪═══════════════════════════╪═══════════════════════════╪═══════════════════════════╪═══════════════════════════╪══════════════════════════╪═══════════════════════════╪═══════════════════════════╪═══════════════════════════╪═══════════════════════════╪═══════════════════════════╪═══════════════════════════╪═══════════════════════════╪═══════════════════════════╪═════════════════╪═════════════════╡
# │ exp_opt      ┆      0 ┆ ee_tools.models.resnet_g… ┆ cifar100_train ┆ cifar100_val ┆         100 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆       10000 ┆     10000 ┆    200 ┆    0.1 ┆    0.003 ┆        128 ┆          79 ┆ 15800 ┆      2000000 ┆           100.0 ┆   64 ┆         1 ┆        64 ┆   11220132 ┆ CrossEntropyLoss ┆ SGD       ┆ CosineAnnealingLR ┆ [1, 2, … 200]  ┆ [1, 2, … 200]  ┆ [0.1, 0.099994, … 0.0000… ┆ [4.412952, 3.915954, … 0… ┆ [0.0482, 0.0867, … 0.999… ┆ [null, 4.041228, … 1.754… ┆ [null, 0.0724, … 0.5904] ┆ [101.96273, 80.656737, …… ┆ [2.043378, 1.330684, … 1… ┆ [{3.697158,7.276463,0.16… ┆ [{0.288584,0.032949,0.02… ┆ [0.019641, 0.016612, … 0… ┆ [3.1892, 5.319546, … 396… ┆ [3.189377, 5.029107, … 3… ┆ [0.066926, 0.13655, … 13… ┆ null            ┆ null            │
# │ exp_opt      ┆      1 ┆ ee_tools.models.resnet_g… ┆ cifar100_train ┆ cifar100_val ┆         100 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆       10000 ┆     10000 ┆    200 ┆    0.1 ┆    0.003 ┆        128 ┆          79 ┆ 15800 ┆      2000000 ┆           100.0 ┆   16 ┆        16 ┆        64 ┆   11409216 ┆ CrossEntropyLoss ┆ SGD       ┆ CosineAnnealingLR ┆ [1, 2, … 200]  ┆ [1, 2, … 200]  ┆ [0.1, 0.099994, … 0.0000… ┆ [4.483505, 4.239091, … 3… ┆ [0.03, 0.0667, … 0.2088]  ┆ [null, 4.365785, … 3.499… ┆ [null, 0.0481, … 0.1858] ┆ [204.116164, 160.700341,… ┆ [0.419628, 0.441169, … 2… ┆ [{8.89473,14.525507,0.07… ┆ [{0.162078,0.013942,0.01… ┆ [0.002052, 0.002774, … 0… ┆ [5.16227, 11.367722, … 1… ┆ [5.162441, 10.067055, … … ┆ [0.066926, 0.13655, … 13… ┆ null            ┆ null            │
# │ exp_opt      ┆      2 ┆ ee_tools.models.resnet_g… ┆ cifar100_train ┆ cifar100_val ┆         100 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆       10000 ┆     10000 ┆    200 ┆    0.1 ┆    0.003 ┆        128 ┆          79 ┆ 15800 ┆      2000000 ┆           100.0 ┆    8 ┆        64 ┆        64 ┆   11664128 ┆ CrossEntropyLoss ┆ SGD       ┆ CosineAnnealingLR ┆ [1, 2, … 200]  ┆ [1, 2, … 200]  ┆ [0.1, 0.099994, … 0.0000… ┆ [4.593002, 4.548108, … 4… ┆ [0.0217, 0.0429, … 0.01]  ┆ [null, 4.564884, … 4.605… ┆ [null, 0.0428, … 0.01]   ┆ [290.5511, 228.575706, …… ┆ [0.164309, 0.123004, … 0… ┆ [{17.863414,20.540505,0.… ┆ [{0.0773,0.008201,0.0081… ┆ [0.000565, 0.000538, … 0… ┆ [11.226474, 25.263264, …… ┆ [11.226661, 21.952506, …… ┆ [0.066926, 0.13655, … 13… ┆ null            ┆ null            │
# │ exp_opt      ┆      3 ┆ ee_tools.models.resnet_g… ┆ cifar100_train ┆ cifar100_val ┆         100 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆       10000 ┆     10000 ┆    200 ┆    0.1 ┆    0.003 ┆        128 ┆          79 ┆ 15800 ┆      2000000 ┆           100.0 ┆    4 ┆       256 ┆        64 ┆   12183552 ┆ CrossEntropyLoss ┆ SGD       ┆ CosineAnnealingLR ┆ [1, 2, … 200]  ┆ [1, 2, … 200]  ┆ [0.1, 0.099994, … 0.0000… ┆ [4.604219, 4.601684, … 4… ┆ [0.0134, 0.0205, … 0.01]  ┆ [null, 4.603734, … 4.605… ┆ [null, 0.0149, … 0.01]   ┆ [415.946435, 327.194858,… ┆ [0.061025, 0.047845, … 0… ┆ [{35.544859,29.048969,0.… ┆ [{0.030074,0.003869,0.00… ┆ [0.000147, 0.000146, … 0… ┆ [37.151627, 81.318986, …… ┆ [37.151813, 72.767807, …… ┆ [0.066926, 0.13655, … 13… ┆ null            ┆ null            │
# │ exp_opt      ┆      4 ┆ ee_tools.models.resnet_g… ┆ cifar100_train ┆ cifar100_val ┆         100 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆       10000 ┆     10000 ┆    200 ┆    0.1 ┆    0.001 ┆        128 ┆          79 ┆ 15800 ┆      2000000 ┆           100.0 ┆   64 ┆         1 ┆        64 ┆   11220132 ┆ CrossEntropyLoss ┆ SGD       ┆ CosineAnnealingLR ┆ [1, 2, … 200]  ┆ [1, 2, … 200]  ┆ [0.1, 0.099994, … 0.0000… ┆ [4.467508, 3.962184, … 0… ┆ [0.0434, 0.0779, … 0.999… ┆ [null, 4.192157, … 1.789… ┆ [null, 0.0654, … 0.575]  ┆ [108.726743, 100.865556,… ┆ [1.72552, 1.182769, … 0.… ┆ [{4.07076,7.75086,0.1916… ┆ [{0.322743,0.034822,0.03… ┆ [0.015751, 0.011729, … 0… ┆ [1.877035, 4.013081, … 3… ┆ [1.877198, 3.723323, … 3… ┆ [0.083054, 0.153258, … 1… ┆ null            ┆ null            │
# │ …            ┆      … ┆ …                         ┆ …              ┆ …            ┆           … ┆ …                         ┆ …                         ┆           … ┆         … ┆      … ┆      … ┆        … ┆          … ┆           … ┆     … ┆            … ┆               … ┆    … ┆         … ┆         … ┆          … ┆ …                ┆ …         ┆ …                 ┆ …              ┆ …              ┆ …                         ┆ …                         ┆ …                         ┆ …                         ┆ …                        ┆ …                         ┆ …                         ┆ …                         ┆ …                         ┆ …                         ┆ …                         ┆ …                         ┆ …                         ┆ …               ┆ …               │
# │ exp_opt_4090 ┆    103 ┆ ee_tools.models.resnet_g… ┆ cifar100_train ┆ cifar100_val ┆         100 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆         500 ┆     10000 ┆   4000 ┆  0.005 ┆  0.00001 ┆        128 ┆           4 ┆ 16000 ┆      2000000 ┆             5.0 ┆    2 ┆      1024 ┆        64 ┆   13260800 ┆ CrossEntropyLoss ┆ AdamW     ┆ CosineAnnealingLR ┆ [1, 2, … 4000] ┆ [1, 2, … 4000] ┆ [0.005, 0.005, … 7.7106e… ┆ [4.621583, 4.569277, … 0… ┆ [0.008, 0.034, … 1.0]     ┆ [null, null, … 7.634691]  ┆ [null, null, … 0.1454]   ┆ [665.365187, 666.63039, … ┆ [0.025313, 0.025191, … 0… ┆ [{78.480155,45.257066,0.… ┆ [{0.012432,0.001903,0.00… ┆ [0.000038, 0.000038, … 7… ┆ [1.741917, 3.480397, … 8… ┆ [1.741922, 3.48041, … 69… ┆ [0.041401, 0.083503, … 1… ┆ null            ┆ null            │
# │ exp_opt_4090 ┆    104 ┆ ee_tools.models.resnet_g… ┆ cifar100_train ┆ cifar100_val ┆         100 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆         500 ┆     10000 ┆   4000 ┆  0.005 ┆ 0.000001 ┆        128 ┆           4 ┆ 16000 ┆      2000000 ┆             5.0 ┆   32 ┆         4 ┆        64 ┆   11282960 ┆ CrossEntropyLoss ┆ AdamW     ┆ CosineAnnealingLR ┆ [1, 2, … 4000] ┆ [1, 2, … 4000] ┆ [0.005, 0.005, … 7.7106e… ┆ [5.02388, 4.752704, … 0.… ┆ [0.008, 0.012, … 1.0]     ┆ [null, null, … 19.657925… ┆ [null, null, … 0.0873]   ┆ [161.304689, 167.092122,… ┆ [1.5792, 1.316162, … 0.0… ┆ [{4.93108,11.305917,0.08… ┆ [{0.78528,0.043143,0.034… ┆ [0.009789, 0.007881, … 4… ┆ [0.165644, 0.332117, … 7… ┆ [0.165649, 0.332127, … 6… ┆ [0.042879, 0.081938, … 1… ┆ null            ┆ null            │
# │ exp_opt_4090 ┆    105 ┆ ee_tools.models.resnet_g… ┆ cifar100_train ┆ cifar100_val ┆         100 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆         500 ┆     10000 ┆   4000 ┆  0.005 ┆ 0.000001 ┆        128 ┆           4 ┆ 16000 ┆      2000000 ┆             5.0 ┆    2 ┆      1024 ┆        64 ┆   13260800 ┆ CrossEntropyLoss ┆ AdamW     ┆ CosineAnnealingLR ┆ [1, 2, … 4000] ┆ [1, 2, … 4000] ┆ [0.005, 0.005, … 7.7106e… ┆ [4.624578, 4.572032, … 0… ┆ [0.014, 0.042, … 1.0]     ┆ [null, null, … 6.823844]  ┆ [null, null, … 0.1456]   ┆ [665.411079, 666.686976,… ┆ [0.025289, 0.024539, … 0… ┆ [{78.642449,45.24788,0.3… ┆ [{0.012323,0.001922,0.00… ┆ [0.000038, 0.000037, … 1… ┆ [1.738586, 3.482786, … 8… ┆ [1.738591, 3.482797, … 6… ┆ [0.042879, 0.081938, … 1… ┆ null            ┆ null            │
# │ exp_opt_4090 ┆    106 ┆ ee_tools.models.resnet_g… ┆ cifar100_train ┆ cifar100_val ┆         100 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆         500 ┆     10000 ┆   4000 ┆  0.005 ┆      0.0 ┆        128 ┆           4 ┆ 16000 ┆      2000000 ┆             5.0 ┆   32 ┆         4 ┆        64 ┆   11282960 ┆ CrossEntropyLoss ┆ AdamW     ┆ CosineAnnealingLR ┆ [1, 2, … 4000] ┆ [1, 2, … 4000] ┆ [0.005, 0.005, … 7.7106e… ┆ [5.010425, 4.49596, … 0.… ┆ [0.004, 0.028, … 1.0]     ┆ [null, null, … 19.973801… ┆ [null, null, … 0.0898]   ┆ [161.241048, 167.040747,… ┆ [1.358334, 0.931692, … 0… ┆ [{4.92125,11.311829,0.09… ┆ [{0.488088,0.031539,0.02… ┆ [0.008433, 0.005575, … 4… ┆ [0.166414, 0.331925, … 7… ┆ [0.166419, 0.331935, … 6… ┆ [0.056234, 0.097161, … 1… ┆ null            ┆ null            │
# │ exp_opt_4090 ┆    107 ┆ ee_tools.models.resnet_g… ┆ cifar100_train ┆ cifar100_val ┆         100 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆         500 ┆     10000 ┆   4000 ┆  0.005 ┆      0.0 ┆        128 ┆           4 ┆ 16000 ┆      2000000 ┆             5.0 ┆    2 ┆      1024 ┆        64 ┆   13260800 ┆ CrossEntropyLoss ┆ AdamW     ┆ CosineAnnealingLR ┆ [1, 2, … 4000] ┆ [1, 2, … 4000] ┆ [0.005, 0.005, … 7.7106e… ┆ [4.626214, 4.570451, … 0… ┆ [0.016, 0.038, … 1.0]     ┆ [null, null, … 7.170188]  ┆ [null, null, … 0.1441]   ┆ [665.344613, 666.581638,… ┆ [0.025178, 0.024431, … 0… ┆ [{77.933579,45.258731,0.… ┆ [{0.012308,0.001849,0.00… ┆ [0.000038, 0.000037, … 3… ┆ [1.739442, 3.480951, … 8… ┆ [1.739447, 3.480964, … 6… ┆ [0.056234, 0.097161, … 1… ┆ null            ┆ null            │
# └──────────────┴────────┴───────────────────────────┴────────────────┴──────────────┴─────────────┴───────────────────────────┴───────────────────────────┴─────────────┴───────────┴────────┴────────┴──────────┴────────────┴─────────────┴───────┴──────────────┴─────────────────┴──────┴───────────┴───────────┴────────────┴──────────────────┴───────────┴───────────────────┴────────────────┴────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┴──────────────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┴─────────────────┴─────────────────┘

# %%
df_b = df_base
# df_b = df_b.pipe(pl_utils.add_iter_epoch).pipe(pl_utils.unnest_iter)

# df_b = df_b.filter(pl.col("optimizer") == "SGD")
# df_b = df_b.filter(pl.col("train_ndata").is_in([10000, 5000]))
# df_b = df_b.filter(pl.col("model_arc").str.contains("cifar"))

df_b = df_b.pipe(pl_utils.snapshot)

# %%
ext_columns = ["train_dataset", "optimizer"] # この要素ごとにheatmapを表示
piv_values = ["val_acc"] # この値を表示
# piv_values = ["train_acc", "val_acc", "train_loss", "val_loss"]
piv_indices = ["fils", "ensembles"] # 縦軸
piv_on = ["train_ndata"] # 横軸
# piv_on = ["epochs", "wd"] # 横軸


reverse_x = False  # x軸を反転させる場合はTrueに設定
reverse_y = True  # y軸を反転させる場合はTrueに設定

# heatmap
agg = "first"
axis = 0    # None: 正規化なし, 0: 行方向, 1: 列方向

norm = "zscore"  # "minmax", "zscore", None
square_size = 0.75

# graph
graph_size = (4, 3)
ylim = True
x_col = "step"
# x_col = "iter_step"

# %%
import matplotlib.ticker as ticker
import polars as pl

def format_axis_label(val: float | str) -> str:
    """数値を適切な形式（整数、小数、または指数表記）に整形する。"""
    try:
        f_val = float(val)
        if f_val.is_integer():
            return str(int(f_val))
        return f"{f_val:g}"
    except (ValueError, TypeError):
        return str(val)

def format_pivot_columns(df: pl.DataFrame, group_cols: list | None = None) -> pl.DataFrame:
    """Pivotテーブルのカラム数値ソートとインデックスの整形を行う。"""
    new_columns = (
        pl.DataFrame({"cols": df.columns})
        .with_columns(pl.col("cols").cast(pl.Float32, strict=False).alias("numeric"))
        .sort("numeric", maintain_order=True)["cols"]
        .to_list()
    )
    df = df.select(new_columns)

    if group_cols:
        if len(group_cols) == 1:
            idx_alias = group_cols[0]
        else:
            idx_alias = f"({', '.join(group_cols)})"
            df = df.with_columns(
                (pl.lit("(") + pl.concat_str([pl.col(c).cast(pl.String) for c in group_cols], separator=", ") + pl.lit(")")).alias(idx_alias)
            )
        
        existing_cols = [c for c in group_cols if c in df.columns]
        if existing_cols:
            df = df.sort(existing_cols, descending=False).select(idx_alias, pl.col(new_columns).exclude(existing_cols))
            
    return df

# 注意: tools_path, df_b, ext_columns, piv_values, piv_on, piv_indices, agg, 
# square_size, graph_size, norm, axis, x_col, ylim 等の変数は実行環境で定義されている前提とします。
plt.style.use([f'{tools_path}/mplstyles/common.mplstyle'])
plt.rcParams['axes.titleweight'] = 300
plt.rcParams['axes.labelweight'] = 300

ext_columns = ext_columns if isinstance(ext_columns, list) else [ext_columns]
piv_values = piv_values if isinstance(piv_values, list) else [piv_values]
piv_on = piv_on if isinstance(piv_on, list) else [piv_on]

ext_l_df = df_b.select(ext_columns).unique().sort(ext_columns)

for i, ext_row_dict in enumerate(ext_l_df.iter_rows(named=True)):
    try:
        fig, ax = None, None
        for piv_value in piv_values:
            filter_condition = pl.all_horizontal([(pl.col(k) == v) for k, v in ext_row_dict.items()])
            df_ext = df_b.filter(filter_condition)
            
            target_on = piv_on[0]
            if len(piv_on) > 1:
                target_on = f"({', '.join(piv_on)})"
                df_ext = df_ext.with_columns(
                    (pl.lit("(") + pl.concat_str([pl.col(c).cast(pl.String) for c in piv_on], separator=", ") + pl.lit(")")).alias(target_on)
                )

            df_piv = df_ext.pivot(
                values=piv_value, index=piv_indices, on=target_on, sort_columns=True, aggregate_function=agg
            ).pipe(format_pivot_columns, group_cols=piv_indices)
            
            ax_x = df_piv.columns[1:]
            ax_y = df_piv[df_piv.columns[0]]
            data = df_piv.select(ax_x).to_numpy()
            
            # --- 軸ラベルとデータの反転処理 ---
            if reverse_x:
                ax_x = ax_x[::-1]         
                data = data[:, ::-1]      
            if reverse_y:
                ax_y = ax_y.reverse()     
                data = data[::-1, :]      
            # ----------------------------------

            title_parts = [f"{k}: {v}" for k, v in ext_row_dict.items()]
            title_str = ", ".join(title_parts)
            
            if np.issubdtype(data.dtype, np.number):
                annot = data.copy()

                if axis is not None:
                    if norm == "minmax":
                        min_vals = np.nanmin(data, axis=axis, keepdims=True)
                        max_vals = np.nanmax(data, axis=axis, keepdims=True)
                        data = (data - min_vals) / (max_vals - min_vals + 1e-8)
                
                    elif norm == "zscore":
                        mean_vals = np.nanmean(data, axis=axis, keepdims=True)
                        std_vals = np.nanstd(data, axis=axis, keepdims=True)
                        data = (data - mean_vals) / (std_vals + 1e-8)

                if piv_value[-4:] == "_acc":
                    annot *= 100
                
                fig, ax = plt.subplots(figsize=(len(ax_x)*square_size, len(ax_y)*square_size))

                hm_kwargs = {
                    "cmap": "Blues_r",
                    "cbar": False,
                    "fmt": ".2f",
                    "annot_kws": {"size": 11, "fontweight": 500}
                }

                ax = sns.heatmap(data, annot=annot, square=False, **hm_kwargs)
                
                ax.set_title(title_str, fontsize=14)
                ax.set_xlabel(target_on, fontsize=12)
                ax.set_ylabel(ax_y.name, fontsize=12, rotation=90)

                ax.set_xticklabels([format_axis_label(x) for x in ax_x], fontsize=11, rotation=0)
                ax.set_yticklabels([format_axis_label(y) for y in ax_y], fontsize=11, rotation=0)
                
                plt.show()
        
            else:
                plt.style.use([f'{tools_path}/mplstyles/line.mplstyle'])
                df_step = df_ext.pivot(
                    values=x_col, index=piv_indices, on=target_on, sort_columns=True, aggregate_function=agg
                ).pipe(format_pivot_columns, group_cols=piv_indices)

                _ax_x = df_step.columns[1:]
                step_data = df_step.select(_ax_x).to_numpy()
                
                # --- ステップデータの反転処理 ---
                if reverse_x:
                    step_data = step_data[:, ::-1]
                if reverse_y:
                    step_data = step_data[::-1, :]
                # ----------------------------------

                nrows, ncols = data.shape
                
                if fig is None:
                    fig, axes = plt.subplots(
                        nrows, ncols, 
                        figsize=(ncols * graph_size[0], nrows * graph_size[1]), 
                        sharex=False, sharey=False, squeeze=False
                    )
                
                fig.suptitle(title_str, fontsize=16)

                for i in range(nrows):
                    for j in range(ncols):
                        ax = axes[i, j]
                        
                        x_data = step_data[i, j]
                        y_data = data[i, j]
                        
                        if x_data is not None and y_data is not None:
                            filtered_points = [(x, y) for x, y in zip(x_data, y_data) if y is not None and not np.isnan(y)]
                            if len(filtered_points) > 1:
                                sorted_points = sorted(filtered_points, key=lambda point: point[0])
                                x_plot, y_plot = zip(*sorted_points)
                                ax.plot(x_plot, y_plot, label=piv_value)

                        ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: format_axis_label(x)))
                        ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda y, pos: format_axis_label(y)))

                        ax.tick_params(axis='both', which='major') 
                        legend = ax.legend()
                        
                        if ylim:
                            ax.set_ylim([0, 1.005])
            
                for i, row_label in enumerate(ax_y):
                    axes[i, 0].set_ylabel(row_label, rotation=0, ha='right', va='center', fontsize=10)

                for j, col_label in enumerate(ax_x):
                    axes[-1, j].set_xlabel(col_label, fontsize=10)
                    
                fig.supxlabel(target_on, fontsize=12)
                fig.supylabel(ax_y.name, fontsize=12)
                
                plt.tight_layout(rect=[0.02, 0.02, 1, 0.98])
    except ValueError as e:
        print(f"Skipping combination {ext_row_dict} due to error: {e}")

plt.show()
