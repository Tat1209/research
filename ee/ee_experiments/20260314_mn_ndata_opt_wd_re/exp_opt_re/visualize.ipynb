# %%
import sys
from pathlib import Path

import polars as pl
import numpy as np
import matplotlib.pyplot as plt
from cycler import cycler
import seaborn as sns

this_path = Path(__file__) if '__file__' in globals() else Path("<unknown>.ipynb").resolve()
work_path = next((p for p in this_path.parents if p.name == "research"), None)
tools_path = work_path / Path("../torch-tools")
sys.path.append(str(tools_path))

from exp_manager import cat_results
import pl_utils

# %%
pl_utils.Config()

p_path = this_path.parent
print(p_path)

paths = [p_path]
# paths = [p_path / "exp_*"]

df_base = cat_results(paths)
df_base = df_base.filter(pl.col("epochs") == pl.col("epoch").list.last())

# df_base.pipe(pl_utils.resolve_nested).write_csv(p_path / "df_base.csv")

print(df_base.columns)
print(df_base)
# Out:
# /newssd/projects/tat/research/ee/ee_experiments/20260314_mn_ndata_opt_wd_re/exp_opt_re
# ['exp_name', 'run_id', 'model_arc', 'train_dataset', 'val_dataset', 'num_classes', 'train_trans', 'val_trans', 'train_ndata', 'val_ndata', 'ipc', 'ipc_is_balanced', 'ipc_info', 'epochs', 'max_lr', 'wd', 'batch_size', 'iters/epoch', 'iters', 'processed_ndata', 'div', 'ensembles', 'scale_ch', 'refiner', 'num_params', 'criterion', 'optimizer', 'scheduler', 'step', 'epoch', 'lr', 'train_loss', 'train_acc', 'val_loss', 'val_acc', 'dur_total_core', 'dur_total_core_fmt', 'dur_train_core', 'dur_train_core_fmt', 'dur_total', 'dur_total_fmt', 'dur_train', 'dur_train_fmt', 'progress']
# shape: (530, 44)
# ┌────────────┬───────────────────────────┬───────────┬────────────────┬───────────────┬─────────────┬───────────────────────────┬───────────────────────────┬─────────────┬───────────┬───────┬─────────────────┬───────────────────────────┬────────┬────────┬──────┬────────────┬─────────────┬───────┬─────────────────┬─────┬───────────┬──────────┬───────────────────────────┬────────────┬──────────────────┬───────────┬───────────────────┬────────────────┬────────────────┬───────────────────────────┬───────────────────────────┬───────────────────────────┬───────────────────────────┬──────────────────────────┬───────────────────────────┬───────────────────────────┬───────────────────────────┬───────────────────────────┬───────────────────────────┬───────────────────────────┬───────────────────────────┬───────────────────────────┬───────────────────────────┐
# │ exp_name   ┆ run_id                    ┆ model_arc ┆ train_dataset  ┆ val_dataset   ┆ num_classes ┆ train_trans               ┆ val_trans                 ┆ train_ndata ┆ val_ndata ┆   ipc ┆ ipc_is_balanced ┆ ipc_info                  ┆ epochs ┆ max_lr ┆   wd ┆ batch_size ┆ iters/epoch ┆ iters ┆ processed_ndata ┆ div ┆ ensembles ┆ scale_ch ┆ refiner                   ┆ num_params ┆ criterion        ┆ optimizer ┆ scheduler         ┆ step           ┆ epoch          ┆ lr                        ┆ train_loss                ┆ train_acc                 ┆ val_loss                  ┆ val_acc                  ┆ dur_total_core            ┆ dur_total_core_fmt        ┆ dur_train_core            ┆ dur_train_core_fmt        ┆ dur_total                 ┆ dur_total_fmt             ┆ dur_train                 ┆ dur_train_fmt             ┆ progress                  │
# │ ---        ┆ ---                       ┆ ---       ┆ ---            ┆ ---           ┆         --- ┆ ---                       ┆ ---                       ┆         --- ┆       --- ┆   --- ┆ ---             ┆ ---                       ┆    --- ┆    --- ┆  --- ┆        --- ┆         --- ┆   --- ┆             --- ┆ --- ┆       --- ┆      --- ┆ ---                       ┆        --- ┆ ---              ┆ ---       ┆ ---               ┆ ---            ┆ ---            ┆ ---                       ┆ ---                       ┆ ---                       ┆ ---                       ┆ ---                      ┆ ---                       ┆ ---                       ┆ ---                       ┆ ---                       ┆ ---                       ┆ ---                       ┆ ---                       ┆ ---                       ┆ ---                       │
# │ str        ┆ str                       ┆ str       ┆ str            ┆ str           ┆         i64 ┆ str                       ┆ str                       ┆         i64 ┆       i64 ┆   f64 ┆ bool            ┆ struct[7]                 ┆    i64 ┆    f64 ┆  f64 ┆        i64 ┆         i64 ┆   i64 ┆             i64 ┆ i64 ┆       i64 ┆      f64 ┆ str                       ┆        i64 ┆ str              ┆ str       ┆ str               ┆ list[i64]      ┆ list[i64]      ┆ list[f64]                 ┆ list[f64]                 ┆ list[f64]                 ┆ list[f64]                 ┆ list[f64]                ┆ list[f64]                 ┆ list[str]                 ┆ list[f64]                 ┆ list[str]                 ┆ list[f64]                 ┆ list[str]                 ┆ list[f64]                 ┆ list[str]                 ┆ list[str]                 │
# ╞════════════╪═══════════════════════════╪═══════════╪════════════════╪═══════════════╪═════════════╪═══════════════════════════╪═══════════════════════════╪═════════════╪═══════════╪═══════╪═════════════════╪═══════════════════════════╪════════╪════════╪══════╪════════════╪═════════════╪═══════╪═════════════════╪═════╪═══════════╪══════════╪═══════════════════════════╪════════════╪══════════════════╪═══════════╪═══════════════════╪════════════════╪════════════════╪═══════════════════════════╪═══════════════════════════╪═══════════════════════════╪═══════════════════════════╪══════════════════════════╪═══════════════════════════╪═══════════════════════════╪═══════════════════════════╪═══════════════════════════╪═══════════════════════════╪═══════════════════════════╪═══════════════════════════╪═══════════════════════════╪═══════════════════════════╡
# │ exp_opt_re ┆ run_2026-03-14_20-00-36_… ┆ resnet18  ┆ cifar100_train ┆ cifar100_test ┆         100 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆        5000 ┆     10000 ┆  50.0 ┆ true            ┆ {true,50,50,50,50.0,0.0,… ┆    400 ┆    0.1 ┆ 0.01 ┆        128 ┆          40 ┆ 16000 ┆         2000000 ┆   1 ┆         1 ┆      1.0 ┆ Base._remove_downsample(… ┆   11220132 ┆ CrossEntropyLoss ┆ SGD       ┆ CosineAnnealingLR ┆ [1, 2, … 400]  ┆ [1, 2, … 400]  ┆ [0.1, 0.099998, … 0.0000… ┆ [4.623094, 4.152752, … 2… ┆ [0.029, 0.0568, … 0.3422… ┆ [null, null, … 3.11996]   ┆ [null, null, … 0.2352]   ┆ [25.805375, 26.355296, …… ┆ ["25.8s", "26.4s", … "3.… ┆ [25.805545, 26.355721, …… ┆ ["25.8s", "26.4s", … "3.… ┆ [26.462403, 27.918511, …… ┆ ["26.5s", "27.9s", … "10… ┆ [26.46241, 27.918522, … … ┆ ["26.5s", "27.9s", … "7.… ┆ ["0.2%", "0.5%", … "100.… │
# │ exp_opt_re ┆ run_2026-03-14_20-00-37_… ┆ resnet18  ┆ cifar100_train ┆ cifar100_test ┆         100 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆       10000 ┆     10000 ┆ 100.0 ┆ true            ┆ {true,100,100,100,100.0,… ┆    200 ┆    0.1 ┆ 0.01 ┆        128 ┆          79 ┆ 15800 ┆         2000000 ┆   2 ┆         4 ┆      0.5 ┆ Base._remove_downsample(… ┆   11282960 ┆ CrossEntropyLoss ┆ SGD       ┆ CosineAnnealingLR ┆ [1, 2, … 200]  ┆ [1, 2, … 200]  ┆ [0.1, 0.099994, … 0.0000… ┆ [4.302963, 4.033531, … 4… ┆ [0.047, 0.0794, … 0.0769… ┆ [null, 4.482996, … 4.094… ┆ [null, 0.0211, … 0.0765] ┆ [43.024491, 50.380146, …… ┆ ["43.0s", "50.4s", … "7.… ┆ [43.02473, 44.83938, … 3… ┆ ["43.0s", "44.8s", … "6.… ┆ [43.581459, 58.529126, …… ┆ ["43.6s", "58.5s", … "10… ┆ [43.581467, 45.835588, …… ┆ ["43.6s", "45.8s", … "8.… ┆ ["0.5%", "1.0%", … "100.… │
# │ exp_opt_re ┆ run_2026-03-14_20-00-37_… ┆ resnet18  ┆ cifar100_train ┆ cifar100_test ┆         100 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆       10000 ┆     10000 ┆ 100.0 ┆ true            ┆ {true,100,100,100,100.0,… ┆    200 ┆    0.1 ┆ 0.01 ┆        128 ┆          79 ┆ 15800 ┆         2000000 ┆   1 ┆         1 ┆      1.0 ┆ Base._remove_downsample(… ┆   11220132 ┆ CrossEntropyLoss ┆ SGD       ┆ CosineAnnealingLR ┆ [1, 2, … 200]  ┆ [1, 2, … 200]  ┆ [0.1, 0.099994, … 0.0000… ┆ [4.352385, 4.009433, … 0… ┆ [0.0452, 0.0744, … 0.789… ┆ [null, 4.394811, … 1.892… ┆ [null, 0.0443, … 0.4979] ┆ [23.683911, 27.671966, …… ┆ ["23.7s", "27.7s", … "3.… ┆ [23.684212, 24.585306, …… ┆ ["23.7s", "24.6s", … "3.… ┆ [25.117656, 37.515449, …… ┆ ["25.1s", "37.5s", … "10… ┆ [25.117664, 27.29803, … … ┆ ["25.1s", "27.3s", … "7.… ┆ ["0.5%", "1.0%", … "100.… │
# │ exp_opt_re ┆ run_2026-03-14_20-00-37_… ┆ resnet18  ┆ cifar100_train ┆ cifar100_test ┆         100 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆       10000 ┆     10000 ┆ 100.0 ┆ true            ┆ {true,100,100,100,100.0,… ┆    200 ┆    0.1 ┆ 0.01 ┆        128 ┆          79 ┆ 15800 ┆         2000000 ┆   4 ┆        16 ┆     0.25 ┆ Base._remove_downsample(… ┆   11409216 ┆ CrossEntropyLoss ┆ SGD       ┆ CosineAnnealingLR ┆ [1, 2, … 200]  ┆ [1, 2, … 200]  ┆ [0.1, 0.099994, … 0.0000… ┆ [4.507509, 4.403621, … 4… ┆ [0.03, 0.0475, … 0.01]    ┆ [null, 4.598266, … 4.605… ┆ [null, 0.0178, … 0.01]   ┆ [16.747825, 28.039804, …… ┆ ["16.7s", "28.0s", … "12… ┆ [16.748096, 20.118495, …… ┆ ["16.7s", "20.1s", … "11… ┆ [16.915388, 34.687709, …… ┆ ["16.9s", "34.7s", … "14… ┆ [16.915395, 20.392172, …… ┆ ["16.9s", "20.4s", … "11… ┆ ["0.5%", "1.0%", … "100.… │
# │ exp_opt_re ┆ run_2026-03-14_20-00-38_… ┆ resnet18  ┆ cifar100_train ┆ cifar100_test ┆         100 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆       10000 ┆     10000 ┆ 100.0 ┆ true            ┆ {true,100,100,100,100.0,… ┆    200 ┆    0.1 ┆ 0.01 ┆        128 ┆          79 ┆ 15800 ┆         2000000 ┆  16 ┆       256 ┆   0.0625 ┆ Base._remove_downsample(… ┆   12183552 ┆ CrossEntropyLoss ┆ SGD       ┆ CosineAnnealingLR ┆ [1, 2, … 200]  ┆ [1, 2, … 200]  ┆ [0.1, 0.099994, … 0.0000… ┆ [4.604515, 4.604304, … 4… ┆ [0.0159, 0.0232, … 0.01]  ┆ [null, 4.605159, … 4.605… ┆ [null, 0.0102, … 0.01]   ┆ [39.972119, 65.808967, …… ┆ ["40.0s", "1.1m", … "53.… ┆ [39.972607, 54.2294, … 2… ┆ ["40.0s", "54.2s", … "47… ┆ [40.102278, 72.077315, …… ┆ ["40.1s", "1.2m", … "54.… ┆ [40.102286, 54.512682, …… ┆ ["40.1s", "54.5s", … "48… ┆ ["0.5%", "1.0%", … "100.… │
# │ …          ┆ …                         ┆ …         ┆ …              ┆ …             ┆           … ┆ …                         ┆ …                         ┆           … ┆         … ┆     … ┆ …               ┆ …                         ┆      … ┆      … ┆    … ┆          … ┆           … ┆     … ┆               … ┆   … ┆         … ┆        … ┆ …                         ┆          … ┆ …                ┆ …         ┆ …                 ┆ …              ┆ …              ┆ …                         ┆ …                         ┆ …                         ┆ …                         ┆ …                        ┆ …                         ┆ …                         ┆ …                         ┆ …                         ┆ …                         ┆ …                         ┆ …                         ┆ …                         ┆ …                         │
# │ exp_opt_re ┆ run_2026-03-17_05-22-00_… ┆ resnet18  ┆ cifar100_train ┆ cifar100_test ┆         100 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆         500 ┆     10000 ┆   5.0 ┆ true            ┆ {true,5,5,5,5.0,0.0,1.0}  ┆   4000 ┆  0.005 ┆ 30.0 ┆        128 ┆           4 ┆ 16000 ┆         2000000 ┆   2 ┆         4 ┆      0.5 ┆ Base._remove_downsample(… ┆   11282960 ┆ CrossEntropyLoss ┆ AdamW     ┆ CosineAnnealingLR ┆ [1, 2, … 4000] ┆ [1, 2, … 4000] ┆ [0.005, 0.005, … 7.7106e… ┆ [4.800721, 4.571226, … 4… ┆ [0.01, 0.014, … 0.01]     ┆ [null, null, … 4.60517]   ┆ [null, null, … 0.01]     ┆ [9.277125, 9.526866, … 4… ┆ ["9.3s", "9.5s", … "6.7m… ┆ [9.27716, 9.526939, … 35… ┆ ["9.3s", "9.5s", … "6.0m… ┆ [9.340822, 9.653178, … 7… ┆ ["9.3s", "9.7s", … "12.5… ┆ [9.340826, 9.653186, … 6… ┆ ["9.3s", "9.7s", … "10.3… ┆ ["0.0%", "0.1%", … "100.… │
# │ exp_opt_re ┆ run_2026-03-17_05-33-59_… ┆ resnet18  ┆ cifar100_train ┆ cifar100_test ┆         100 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆         500 ┆     10000 ┆   5.0 ┆ true            ┆ {true,5,5,5,5.0,0.0,1.0}  ┆   4000 ┆  0.005 ┆ 30.0 ┆        128 ┆           4 ┆ 16000 ┆         2000000 ┆   4 ┆        16 ┆     0.25 ┆ Base._remove_downsample(… ┆   11409216 ┆ CrossEntropyLoss ┆ AdamW     ┆ CosineAnnealingLR ┆ [1, 2, … 4000] ┆ [1, 2, … 4000] ┆ [0.005, 0.005, … 7.7106e… ┆ [4.69829, 4.502953, … 4.… ┆ [0.01, 0.028, … 0.01]     ┆ [null, null, … 4.60517]   ┆ [null, null, … 0.01]     ┆ [9.397893, 9.667865, … 7… ┆ ["9.4s", "9.7s", … "12.5… ┆ [9.397929, 9.667912, … 6… ┆ ["9.4s", "9.7s", … "11.2… ┆ [9.457867, 9.796947, … 1… ┆ ["9.5s", "9.8s", … "17.6… ┆ [9.457874, 9.796957, … 9… ┆ ["9.5s", "9.8s", … "15.2… ┆ ["0.0%", "0.1%", … "100.… │
# │ exp_opt_re ┆ run_2026-03-17_05-35-00_… ┆ resnet18  ┆ cifar100_train ┆ cifar100_test ┆         100 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆         500 ┆     10000 ┆   5.0 ┆ true            ┆ {true,5,5,5,5.0,0.0,1.0}  ┆   4000 ┆  0.005 ┆ 30.0 ┆        128 ┆           4 ┆ 16000 ┆         2000000 ┆   8 ┆        64 ┆    0.125 ┆ Base._remove_downsample(… ┆   11664128 ┆ CrossEntropyLoss ┆ AdamW     ┆ CosineAnnealingLR ┆ [1, 2, … 4000] ┆ [1, 2, … 4000] ┆ [0.005, 0.005, … 7.7106e… ┆ [4.634403, 4.538442, … 4… ┆ [0.006, 0.04, … 0.01]     ┆ [null, null, … 4.60517]   ┆ [null, null, … 0.01]     ┆ [18.866623, 19.372339, …… ┆ ["18.9s", "19.4s", … "24… ┆ [18.866656, 19.372385, …… ┆ ["18.9s", "19.4s", … "21… ┆ [18.925285, 19.529852, …… ┆ ["18.9s", "19.5s", … "29… ┆ [18.925292, 19.529862, …… ┆ ["18.9s", "19.5s", … "25… ┆ ["0.0%", "0.1%", … "100.… │
# │ exp_opt_re ┆ run_2026-03-17_05-52-03_… ┆ resnet18  ┆ cifar100_train ┆ cifar100_test ┆         100 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆         500 ┆     10000 ┆   5.0 ┆ true            ┆ {true,5,5,5,5.0,0.0,1.0}  ┆   4000 ┆  0.005 ┆ 30.0 ┆        128 ┆           4 ┆ 16000 ┆         2000000 ┆  16 ┆       256 ┆   0.0625 ┆ Base._remove_downsample(… ┆   12183552 ┆ CrossEntropyLoss ┆ AdamW     ┆ CosineAnnealingLR ┆ [1, 2, … 4000] ┆ [1, 2, … 4000] ┆ [0.005, 0.005, … 7.7106e… ┆ [4.62708, 4.576878, … 4.… ┆ [0.006, 0.038, … 0.01]    ┆ [null, null, … 4.60517]   ┆ [null, null, … 0.01]     ┆ [18.866097, 19.81342, … … ┆ ["18.9s", "19.8s", … "53… ┆ [18.866134, 19.813476, …… ┆ ["18.9s", "19.8s", … "47… ┆ [18.926715, 19.968994, …… ┆ ["18.9s", "20.0s", … "57… ┆ [18.926724, 19.969005, …… ┆ ["18.9s", "20.0s", … "51… ┆ ["0.0%", "0.1%", … "100.… │
# │ exp_opt_re ┆ run_2026-03-17_06-00-09_… ┆ resnet18  ┆ cifar100_train ┆ cifar100_test ┆         100 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆         500 ┆     10000 ┆   5.0 ┆ true            ┆ {true,5,5,5,5.0,0.0,1.0}  ┆   4000 ┆  0.005 ┆ 30.0 ┆        128 ┆           4 ┆ 16000 ┆         2000000 ┆  32 ┆      1024 ┆  0.03125 ┆ Base._remove_downsample(… ┆   13260800 ┆ CrossEntropyLoss ┆ AdamW     ┆ CosineAnnealingLR ┆ [1, 2, … 4000] ┆ [1, 2, … 4000] ┆ [0.005, 0.005, … 7.7106e… ┆ [4.617147, 4.594838, … 4… ┆ [0.006, 0.024, … 0.01]    ┆ [null, null, … 4.60517]   ┆ [null, null, … 0.01]     ┆ [23.254295, 26.229421, …… ┆ ["23.3s", "26.2s", … "2.… ┆ [23.254322, 26.229465, …… ┆ ["23.3s", "26.2s", … "2.… ┆ [23.313831, 26.351158, …… ┆ ["23.3s", "26.4s", … "2.… ┆ [23.313835, 26.351165, …… ┆ ["23.3s", "26.4s", … "2.… ┆ ["0.0%", "0.1%", … "100.… │
# └────────────┴───────────────────────────┴───────────┴────────────────┴───────────────┴─────────────┴───────────────────────────┴───────────────────────────┴─────────────┴───────────┴───────┴─────────────────┴───────────────────────────┴────────┴────────┴──────┴────────────┴─────────────┴───────┴─────────────────┴─────┴───────────┴──────────┴───────────────────────────┴────────────┴──────────────────┴───────────┴───────────────────┴────────────────┴────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┴──────────────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┘

# %%
df_b = df_base
# df_b = df_b.pipe(pl_utils.add_iter_epoch).pipe(pl_utils.unnest_iter)

# df_b = df_b.filter(pl.col("optimizer") == "SGD")
# df_b = df_b.filter(pl.col("train_ndata").is_in([10000, 5000]))
# df_b = df_b.filter(pl.col("model_arc").str.contains("cifar"))

df_b = df_b.pipe(pl_utils.snapshot)

# %%
ext_columns = ["optimizer", "ipc"] # この要素ごとにheatmapを表示
piv_values = ["val_acc"] # この値を表示
# piv_values = ["train_acc", "val_acc", "train_loss", "val_loss"]
piv_indices = ["div", "ensembles"] # 縦軸
piv_on = ["wd"] # 横軸
# piv_on = ["epochs", "wd"] # 横軸


reverse_x = False  # x軸を反転させる場合はTrueに設定
reverse_y = False  # y軸を反転させる場合はTrueに設定

# heatmap
agg = "first"
axis = None    # None: 正規化なし, 0: 行方向, 1: 列方向
# axis = 0    # None: 正規化なし, 0: 行方向, 1: 列方向

norm = "zscore"  # "minmax", "zscore", None
square_size = 0.75

# graph
graph_size = (4, 3)
ylim = True
x_col = "step"
# x_col = "iter_step"

# %%
import matplotlib.ticker as ticker
import polars as pl

def format_axis_label(val: float | str) -> str:
    """数値を適切な形式（整数、小数、または指数表記）に整形する。"""
    try:
        f_val = float(val)
        if f_val.is_integer():
            return str(int(f_val))
        return f"{f_val:g}"
    except (ValueError, TypeError):
        return str(val)

def format_pivot_columns(df: pl.DataFrame, group_cols: list | None = None) -> pl.DataFrame:
    """Pivotテーブルのカラム数値ソートとインデックスの整形を行う。"""
    new_columns = (
        pl.DataFrame({"cols": df.columns})
        .with_columns(pl.col("cols").cast(pl.Float32, strict=False).alias("numeric"))
        .sort("numeric", maintain_order=True)["cols"]
        .to_list()
    )
    df = df.select(new_columns)

    if group_cols:
        if len(group_cols) == 1:
            idx_alias = group_cols[0]
        else:
            idx_alias = f"({', '.join(group_cols)})"
            df = df.with_columns(
                (pl.lit("(") + pl.concat_str([pl.col(c).cast(pl.String) for c in group_cols], separator=", ") + pl.lit(")")).alias(idx_alias)
            )
        
        existing_cols = [c for c in group_cols if c in df.columns]
        if existing_cols:
            df = df.sort(existing_cols, descending=False).select(idx_alias, pl.col(new_columns).exclude(existing_cols))
            
    return df

# 注意: tools_path, df_b, ext_columns, piv_values, piv_on, piv_indices, agg, 
# square_size, graph_size, norm, axis, x_col, ylim 等の変数は実行環境で定義されている前提とします。
plt.style.use([f'{tools_path}/mplstyles/common.mplstyle'])
plt.rcParams['axes.titleweight'] = 300
plt.rcParams['axes.labelweight'] = 300

ext_columns = ext_columns if isinstance(ext_columns, list) else [ext_columns]
piv_values = piv_values if isinstance(piv_values, list) else [piv_values]
piv_on = piv_on if isinstance(piv_on, list) else [piv_on]

ext_l_df = df_b.select(ext_columns).unique().sort(ext_columns)

for i, ext_row_dict in enumerate(ext_l_df.iter_rows(named=True)):
    try:
        fig, ax = None, None
        for piv_value in piv_values:
            filter_condition = pl.all_horizontal([(pl.col(k) == v) for k, v in ext_row_dict.items()])
            df_ext = df_b.filter(filter_condition)
            
            target_on = piv_on[0]
            if len(piv_on) > 1:
                target_on = f"({', '.join(piv_on)})"
                df_ext = df_ext.with_columns(
                    (pl.lit("(") + pl.concat_str([pl.col(c).cast(pl.String) for c in piv_on], separator=", ") + pl.lit(")")).alias(target_on)
                )

            df_piv = df_ext.pivot(
                values=piv_value, index=piv_indices, on=target_on, sort_columns=True, aggregate_function=agg
            ).pipe(format_pivot_columns, group_cols=piv_indices)
            
            ax_x = df_piv.columns[1:]
            ax_y = df_piv[df_piv.columns[0]]
            data = df_piv.select(ax_x).to_numpy()
            
            # --- 軸ラベルとデータの反転処理 ---
            if reverse_x:
                ax_x = ax_x[::-1]         
                data = data[:, ::-1]      
            if reverse_y:
                ax_y = ax_y.reverse()     
                data = data[::-1, :]      
            # ----------------------------------

            title_parts = [f"{k}: {v}" for k, v in ext_row_dict.items()]
            title_str = ", ".join(title_parts)
            
            if np.issubdtype(data.dtype, np.number):
                annot = data.copy()

                if axis is not None:
                    if norm == "minmax":
                        min_vals = np.nanmin(data, axis=axis, keepdims=True)
                        max_vals = np.nanmax(data, axis=axis, keepdims=True)
                        data = (data - min_vals) / (max_vals - min_vals + 1e-8)
                
                    elif norm == "zscore":
                        mean_vals = np.nanmean(data, axis=axis, keepdims=True)
                        std_vals = np.nanstd(data, axis=axis, keepdims=True)
                        data = (data - mean_vals) / (std_vals + 1e-8)

                if piv_value[-4:] == "_acc":
                    annot *= 100
                
                fig, ax = plt.subplots(figsize=(len(ax_x)*square_size, len(ax_y)*square_size))

                hm_kwargs = {
                    "cmap": "Blues_r",
                    "cbar": False,
                    "fmt": ".2f",
                    "annot_kws": {"size": 11, "fontweight": 500}
                }

                ax = sns.heatmap(data, annot=annot, square=False, **hm_kwargs)
                
                ax.set_title(title_str, fontsize=14)
                ax.set_xlabel(target_on, fontsize=12)
                ax.set_ylabel(ax_y.name, fontsize=12, rotation=90)

                ax.set_xticklabels([format_axis_label(x) for x in ax_x], fontsize=11, rotation=0)
                ax.set_yticklabels([format_axis_label(y) for y in ax_y], fontsize=11, rotation=0)
                
                plt.show()
        
            else:
                plt.style.use([f'{tools_path}/mplstyles/line.mplstyle'])
                df_step = df_ext.pivot(
                    values=x_col, index=piv_indices, on=target_on, sort_columns=True, aggregate_function=agg
                ).pipe(format_pivot_columns, group_cols=piv_indices)

                _ax_x = df_step.columns[1:]
                step_data = df_step.select(_ax_x).to_numpy()
                
                # --- ステップデータの反転処理 ---
                if reverse_x:
                    step_data = step_data[:, ::-1]
                if reverse_y:
                    step_data = step_data[::-1, :]
                # ----------------------------------

                nrows, ncols = data.shape
                
                if fig is None:
                    fig, axes = plt.subplots(
                        nrows, ncols, 
                        figsize=(ncols * graph_size[0], nrows * graph_size[1]), 
                        sharex=False, sharey=False, squeeze=False
                    )
                
                fig.suptitle(title_str, fontsize=16)

                for i in range(nrows):
                    for j in range(ncols):
                        ax = axes[i, j]
                        
                        x_data = step_data[i, j]
                        y_data = data[i, j]
                        
                        if x_data is not None and y_data is not None:
                            filtered_points = [(x, y) for x, y in zip(x_data, y_data) if y is not None and not np.isnan(y)]
                            if len(filtered_points) > 1:
                                sorted_points = sorted(filtered_points, key=lambda point: point[0])
                                x_plot, y_plot = zip(*sorted_points)
                                ax.plot(x_plot, y_plot, label=piv_value)

                        ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: format_axis_label(x)))
                        ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda y, pos: format_axis_label(y)))

                        ax.tick_params(axis='both', which='major') 
                        legend = ax.legend()
                        
                        if ylim:
                            ax.set_ylim([0, 1.005])
            
                for i, row_label in enumerate(ax_y):
                    axes[i, 0].set_ylabel(row_label, rotation=0, ha='right', va='center', fontsize=10)

                for j, col_label in enumerate(ax_x):
                    axes[-1, j].set_xlabel(col_label, fontsize=10)
                    
                fig.supxlabel(target_on, fontsize=12)
                fig.supylabel(ax_y.name, fontsize=12)
                
                plt.tight_layout(rect=[0.02, 0.02, 1, 0.98])
    except ValueError as e:
        print(f"Skipping combination {ext_row_dict} due to error: {e}")

plt.show()
