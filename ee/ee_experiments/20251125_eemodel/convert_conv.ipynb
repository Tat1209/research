# %%
import sys
from pathlib import Path

import torch
from torchvision.transforms import v2 as transforms

this_path = Path(__file__) if '__file__' in globals() else Path("<undefined>.ipynb").resolve()
work_path = next((p for p in this_path.parents if p.name == "research"), None)
tools_path = work_path / Path("../torch-tools")
sys.path.append(str(tools_path))

ee_tools_path_p = work_path / Path("ee")
sys.path.append(str(ee_tools_path_p))

from network import Network, Refiner
from trainer import Trainer
from datasets import fetch_handler

from torch import nn

# %%
from torchvision.models import convnext_base as tv

from ee_tools.ee_refiner import EERefiner

# %%
input_size = (1, 3, 224, 224)

# %%
base_network = tv(num_classes=100)
network = Network(base_network)
net_name = "tv_old"
p = Path(this_path.parent / f"{net_name}.txt")
ti = network.torchinfo(input_size=input_size)
p.write_text(str(ti))
# p.write_text(str(network.base_model))

# base_network = tv(num_classes=100)
# network = Network(EERefiner(base_network).build())
# net_name = "tv_new"
# p = Path(this_path.parent / f"{net_name}.txt")
# ti = network.torchinfo(input_size=input_size)
# p.write_text(str(ti))
#
#
# Out:
# 64622

# %%
base_network = tv(num_classes=100)
network = Network(EERefiner(base_network).multi_narrow(div=2).build())
net_name = "ee_new"
p = Path(this_path.parent / f"{net_name}.txt")
ti = network.torchinfo(input_size=input_size)
p.write_text(str(ti))
# p.write_text(str(network.base_model))

out = network(torch.randn(input_size).to(device=network.device))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/research/.env/lib/python3.14/site-packages/torchinfo/torchinfo.py:295, in forward_pass(model, x, batch_dim, cache_forward_pass, device, mode, **kwargs)
#     294 if isinstance(x, (list, tuple)):
# --> 295     _ = model(*x, **kwargs)
#     296 elif isinstance(x, dict):
#
# File ~/research/.env/lib/python3.14/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/research/.env/lib/python3.14/site-packages/torch/nn/modules/module.py:1881, in Module._call_impl(self, *args, **kwargs)
#    1880 try:
# -> 1881     return inner()
#    1882 except Exception:
#    1883     # run always called hooks if they have not already been run
#    1884     # For now only forward hooks have the always_call option but perhaps
#    1885     # this functionality should be added to full backward hooks as well.
#
# File ~/research/.env/lib/python3.14/site-packages/torch/nn/modules/module.py:1829, in Module._call_impl.<locals>.inner()
#    1827     args = bw_hook.setup_input_hook(args)
# -> 1829 result = forward_call(*args, **kwargs)
#    1830 if _global_forward_hooks or self._forward_hooks:
#
# File ~/research/ee/ee_tools/ee_refiner.py:209, in EEWrapper.forward(self, x)
#     208 x = self.repeater(x)
# --> 209 x = self.model(x)
#     210 x = self.chunk_merge(x)
#
# File ~/research/.env/lib/python3.14/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/research/.env/lib/python3.14/site-packages/torch/nn/modules/module.py:1881, in Module._call_impl(self, *args, **kwargs)
#    1880 try:
# -> 1881     return inner()
#    1882 except Exception:
#    1883     # run always called hooks if they have not already been run
#    1884     # For now only forward hooks have the always_call option but perhaps
#    1885     # this functionality should be added to full backward hooks as well.
#
# File ~/research/.env/lib/python3.14/site-packages/torch/nn/modules/module.py:1829, in Module._call_impl.<locals>.inner()
#    1827     args = bw_hook.setup_input_hook(args)
# -> 1829 result = forward_call(*args, **kwargs)
#    1830 if _global_forward_hooks or self._forward_hooks:
#
# File ~/research/.env/lib/python3.14/site-packages/torchvision/models/convnext.py:177, in ConvNeXt.forward(self, x)
#     176 def forward(self, x: Tensor) -> Tensor:
# --> 177     return self._forward_impl(x)
#
# File ~/research/.env/lib/python3.14/site-packages/torchvision/models/convnext.py:171, in ConvNeXt._forward_impl(self, x)
#     170 def _forward_impl(self, x: Tensor) -> Tensor:
# --> 171     x = self.features(x)
#     172     x = self.avgpool(x)
#
# File ~/research/.env/lib/python3.14/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/research/.env/lib/python3.14/site-packages/torch/nn/modules/module.py:1881, in Module._call_impl(self, *args, **kwargs)
#    1880 try:
# -> 1881     return inner()
#    1882 except Exception:
#    1883     # run always called hooks if they have not already been run
#    1884     # For now only forward hooks have the always_call option but perhaps
#    1885     # this functionality should be added to full backward hooks as well.
#
# File ~/research/.env/lib/python3.14/site-packages/torch/nn/modules/module.py:1829, in Module._call_impl.<locals>.inner()
#    1827     args = bw_hook.setup_input_hook(args)
# -> 1829 result = forward_call(*args, **kwargs)
#    1830 if _global_forward_hooks or self._forward_hooks:
#
# File ~/research/.env/lib/python3.14/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     249 for module in self:
# --> 250     input = module(input)
#     251 return input
#
# File ~/research/.env/lib/python3.14/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/research/.env/lib/python3.14/site-packages/torch/nn/modules/module.py:1881, in Module._call_impl(self, *args, **kwargs)
#    1880 try:
# -> 1881     return inner()
#    1882 except Exception:
#    1883     # run always called hooks if they have not already been run
#    1884     # For now only forward hooks have the always_call option but perhaps
#    1885     # this functionality should be added to full backward hooks as well.
#
# File ~/research/.env/lib/python3.14/site-packages/torch/nn/modules/module.py:1829, in Module._call_impl.<locals>.inner()
#    1827     args = bw_hook.setup_input_hook(args)
# -> 1829 result = forward_call(*args, **kwargs)
#    1830 if _global_forward_hooks or self._forward_hooks:
#
# File ~/research/.env/lib/python3.14/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     249 for module in self:
# --> 250     input = module(input)
#     251 return input
#
# File ~/research/.env/lib/python3.14/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/research/.env/lib/python3.14/site-packages/torch/nn/modules/module.py:1881, in Module._call_impl(self, *args, **kwargs)
#    1880 try:
# -> 1881     return inner()
#    1882 except Exception:
#    1883     # run always called hooks if they have not already been run
#    1884     # For now only forward hooks have the always_call option but perhaps
#    1885     # this functionality should be added to full backward hooks as well.
#
# File ~/research/.env/lib/python3.14/site-packages/torch/nn/modules/module.py:1829, in Module._call_impl.<locals>.inner()
#    1827     args = bw_hook.setup_input_hook(args)
# -> 1829 result = forward_call(*args, **kwargs)
#    1830 if _global_forward_hooks or self._forward_hooks:
#
# File ~/research/.env/lib/python3.14/site-packages/torchvision/models/convnext.py:64, in CNBlock.forward(self, input)
#      63 def forward(self, input: Tensor) -> Tensor:
# ---> 64     result = self.layer_scale * self.block(input)
#      65     result = self.stochastic_depth(result)
#
# RuntimeError: The size of tensor a (128) must match the size of tensor b (256) at non-singleton dimension 1
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 5
#       3 net_name = "ee_new"
#       4 p = Path(this_path.parent / f"{net_name}.txt")
# ----> 5 ti = network.torchinfo(input_size=input_size)
#       6 p.write_text(str(ti))
#       7 # p.write_text(str(network.base_model))
#
# File ~/research/../torch-tools/network.py:65, in Network.torchinfo(self, dl, input_size, batch_dim, verbose, depth, col_names, row_settings, output_path)
#      63 old_stdout = sys.stdout
#      64 sys.stdout = buf
# ---> 65 summary(model=self.base_model, input_size=input_size, batch_dim=batch_dim, depth=depth, verbose=verbose, col_names=col_names, row_settings=row_settings)
#      66 sys.stdout = old_stdout
#      67 summary_str = buf.getvalue()
#
# File ~/research/.env/lib/python3.14/site-packages/torchinfo/torchinfo.py:223, in summary(model, input_size, input_data, batch_dim, cache_forward_pass, col_names, col_width, depth, device, dtypes, mode, row_settings, verbose, **kwargs)
#     216 validate_user_params(
#     217     input_data, input_size, columns, col_width, device, dtypes, verbose
#     218 )
#     220 x, correct_input_size = process_input(
#     221     input_data, input_size, batch_dim, device, dtypes
#     222 )
# --> 223 summary_list = forward_pass(
#     224     model, x, batch_dim, cache_forward_pass, device, model_mode, **kwargs
#     225 )
#     226 formatting = FormattingOptions(depth, verbose, columns, col_width, rows)
#     227 results = ModelStatistics(
#     228     summary_list, correct_input_size, get_total_memory_used(x), formatting
#     229 )
#
# File ~/research/.env/lib/python3.14/site-packages/torchinfo/torchinfo.py:304, in forward_pass(model, x, batch_dim, cache_forward_pass, device, mode, **kwargs)
#     302 except Exception as e:
#     303     executed_layers = [layer for layer in summary_list if layer.executed]
# --> 304     raise RuntimeError(
#     305         "Failed to run torchinfo. See above stack traces for more details. "
#     306         f"Executed layers up to: {executed_layers}"
#     307     ) from e
#     308 finally:
#     309     if hooks:
#
# RuntimeError: Failed to run torchinfo. See above stack traces for more details. Executed layers up to: [RepeatData: 1, Conv2dNormActivation: 3, Conv2d: 4, GroupNorm: 4, Sequential: 5, Conv2d: 6, Permute: 6, PermutedGroupNorm: 6, GroupNorm: 7, GroupedLinear: 6, GELU: 6, GroupedLinear: 6, Permute: 6]

# %%
nm = list(base_network.named_modules())
print(nm)

# %%
base_network = tv(num_classes=100)
network = Network(EERefiner(base_network).cifar_style().build())
net_name = "cifar_new"
p = Path(this_path.parent / f"{net_name}.txt")
ti = network.torchinfo(input_size=input_size)
p.write_text(str(ti))
# Out:
# 111125

# %%
base_network = tv(num_classes=100)
network = Network(EERefiner(base_network).cifar_style().easy_ensemble(ensembles=2).build())
net_name = "cifar_ee_new"
p = Path(this_path.parent / f"{net_name}.txt")
ti = network.torchinfo(input_size=input_size)
p.write_text(str(ti))
# Out:
# 114981
