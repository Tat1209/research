# %%
import sys
from pathlib import Path

import polars as pl
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

work_path = Path(next((p for p in Path("__file__").resolve().parents if p.name == "research"), None))
tools_path = str(work_path / Path("../torch-tools"))
sys.path.append(tools_path)

from run_manager import RunViewer

# %%
nb_path = Path().resolve()
rv = RunViewer(exp_path=nb_path)
df_base = rv.fetch_results()

# %%
display(df_base)
# Out:
# shape: (8, 33)
# ┌────────┬────────────┬────────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ run_id ┆ model_arc  ┆ train_data ┆ val_datas ┆ … ┆ duration_ ┆ dur_total ┆ dur_train ┆ dur_dl_tr │
# │ ---    ┆ ---        ┆ set        ┆ et        ┆   ┆ fmt       ┆ _core     ┆ _core     ┆ ain       │
# │ i64    ┆ str        ┆ ---        ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │        ┆            ┆ str        ┆ str       ┆   ┆ str       ┆ f64       ┆ f64       ┆ f64       │
# ╞════════╪════════════╪════════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 0      ┆ ee_tools.m ┆ cifar100_t ┆ cifar100_ ┆ … ┆ 11.3s     ┆ 10.423187 ┆ 6.501966  ┆ 0.113721  │
# │        ┆ odels.resn ┆ rain       ┆ val       ┆   ┆           ┆           ┆           ┆           │
# │        ┆ et_git_ee  ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │        ┆ …          ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1      ┆ ee_tools.m ┆ cifar100_t ┆ cifar100_ ┆ … ┆ 11.4s     ┆ 10.512322 ┆ 6.439187  ┆ 0.120935  │
# │        ┆ odels.resn ┆ rain       ┆ val       ┆   ┆           ┆           ┆           ┆           │
# │        ┆ et_git_ee  ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │        ┆ …          ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2      ┆ null       ┆ null       ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null      │
# │ 3      ┆ null       ┆ null       ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null      │
# │ 4      ┆ ee_tools.m ┆ cifar100_t ┆ cifar100_ ┆ … ┆ 14.9s     ┆ 5.551604  ┆ 3.219444  ┆ 0.915304  │
# │        ┆ odels.resn ┆ rain       ┆ val       ┆   ┆           ┆           ┆           ┆           │
# │        ┆ et_git_ee  ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │        ┆ …          ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 5      ┆ ee_tools.m ┆ cifar100_t ┆ cifar100_ ┆ … ┆ 11.8s     ┆ 10.875276 ┆ 6.624837  ┆ 0.123263  │
# │        ┆ odels.resn ┆ rain       ┆ val       ┆   ┆           ┆           ┆           ┆           │
# │        ┆ et_git_ee  ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │        ┆ …          ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 6      ┆ ee_tools.m ┆ cifar100_t ┆ cifar100_ ┆ … ┆ 10.8s     ┆ 10.187787 ┆ 6.329602  ┆ 0.112593  │
# │        ┆ odels.resn ┆ rain       ┆ val       ┆   ┆           ┆           ┆           ┆           │
# │        ┆ et_git_ee  ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │        ┆ …          ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 7      ┆ ee_tools.m ┆ cifar100_t ┆ cifar100_ ┆ … ┆ 11.0s     ┆ 10.380332 ┆ 6.470549  ┆ 0.120983  │
# │        ┆ odels.resn ┆ rain       ┆ val       ┆   ┆           ┆           ┆           ┆           │
# │        ┆ et_git_ee  ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │        ┆ …          ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# └────────┴────────────┴────────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
df = df_base

piv_values = ["val_acc"]
piv_index = ["fils", "ensembles"]
piv_on = "train_num" 
# ext_column = "train_num" # このカラムの要素ごとにheatmapを表示
# piv_on = "data_per_class"
ext_column = "num_classes" # このカラムの要素ごとにheatmapを表示

ext_l = df[ext_column].unique()

for ext in ext_l:
    # pivot table 作成
    df_ext = df.filter(pl.col(ext_column) == ext)
    df_piv = df_ext.pivot(values=piv_values, index=piv_index, on=piv_on, sort_columns=True, aggregate_function="mean")

    # カラムが文字列順になっているため、数字部分をソート
    _num_columns = sorted(int(x) for x in df_piv.columns if x.isdigit())
    new_columns = [str(_num_columns.pop(0)) if x.isdigit() else x for x in df_piv.columns]
    df_piv = df_piv.select(new_columns)

    # (fil, ensemble) の形式に
    df_piv = df_piv.with_columns(("(" + pl.col("fils").cast(pl.Utf8) + "," + pl.col("ensembles").cast(pl.Utf8)).alias("(fils, ensembles)") + ")")
    df_piv = df_piv.select(["(fils, ensembles)"] + new_columns).select(pl.exclude(["fils", "ensembles"]))

    # 0列目がx軸ラベル、1列目以降がy軸ラベルになる df を heat map に変換
    square_size = 0.75
    hm_x = df_piv.columns[1:]
    hm_y = df_piv[df_piv.columns[0]]
    data = df_piv.select(hm_x).to_numpy()
    annot = data.copy()

    # 正規化の方向を設定
    axis = 0    # 0: 行方向, 1: 列方向

    # min-max 正規化
    # min_vals = data.min(axis=axis, keepdims=True)
    # max_vals = data.max(axis=axis, keepdims=True)
    # data = (data - min_vals) / (max_vals - min_vals + 1e-8)  # ゼロ除算対策
    
    # Zスコア正規化
    mean_vals = data.mean(axis=axis, keepdims=True)
    std_vals = data.std(axis=axis, keepdims=True)
    data = (data - mean_vals) / (std_vals + 1e-8)  # ゼロ除算対策

    annot *= 100
    sp_kwargs = {}
    hm_kwargs = {"cmap": "Blues_r", "cbar": False, "fmt": ".1f"}

    # plot
    fig, ax = plt.subplots(figsize=(len(hm_x)*square_size, len(hm_y)*square_size), **sp_kwargs)
    ax = sns.heatmap(data, annot=annot, square=True, **hm_kwargs)

    # memo
    # xticklabels=pl.Series(df_piv_val.columns)
    # xticklabels=pl.Series(df_piv_val.columns).str.head(4)

    ax.set_title(f"{ext_column}: {ext}", fontsize=12)
    ax.set_xlabel(piv_on, fontsize=10)
    ax.set_ylabel(hm_y.name, fontsize=10, rotation=90)
    ax.set_xticklabels(hm_x, fontsize=10, rotation=0)
    ax.set_yticklabels(hm_y, fontsize=10, rotation=0)
    plt.show()
# Out:
# /tmp/ipykernel_76299/4200111358.py:14: UserWarning: Comparisons with None always result in null. Consider using `.is_null()` or `.is_not_null()`.
#   df_ext = df.filter(pl.col(ext_column) == ext)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 30
#      28 hm_x = df_piv.columns[1:]
#      29 hm_y = df_piv[df_piv.columns[0]]
# ---> 30 data = df_piv.select(hm_x).to_numpy()
#      31 annot = data.copy()
#      33 # 正規化の方向を設定
#
# File ~/research/.env/lib/python3.12/site-packages/polars/dataframe/frame.py:1892, in DataFrame.to_numpy(self, order, writable, allow_copy, structured, use_pyarrow)
#    1889         out[c] = arrays[idx]
#    1890     return out
# -> 1892 return self._df.to_numpy(order, writable=writable, allow_copy=allow_copy)
#
# File ~/research/.env/lib/python3.12/site-packages/numpy/_core/shape_base.py:291, in vstack(tup, dtype, casting)
#     289 if not isinstance(arrs, tuple):
#     290     arrs = (arrs,)
# --> 291 return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#
# ValueError: need at least one array to concatenate
