# %%
import sys
from pathlib import Path

import polars as pl
import numpy as np
import matplotlib.pyplot as plt
from cycler import cycler
import seaborn as sns

this_path = Path(__file__) if '__file__' in globals() else Path("<unknown>.ipynb").resolve()
work_path = next((p for p in this_path.parents if p.name == "research"), None)
tools_path = work_path / Path("../torch-tools")
sys.path.append(str(tools_path))

from run_manager import RunViewer, cat_results
import pl_utils

# %%
pl_utils.Config()

p_path = this_path.parent
df_base = cat_results([p_path / "exp_opt*"]).filter(pl.col("epochs") == pl.col("epoch").list.last())

print(df_base.columns)
print(df_base)
# Out:
# ['exp_name', 'run_id', 'model_arc', 'train_dataset', 'val_dataset', 'num_classes', 'train_trans', 'val_trans', 'train_ndata', 'val_ndata', 'epochs', 'max_lr', 'wd', 'batch_size', 'iters/epoch', 'iters', 'target_steps', 'ndata_per_class', 'fils', 'ensembles', 'base_fils', 'num_params', 'criterion', 'optimizer', 'scheduler', 'step', 'epoch', 'lr', 'train_loss', 'train_acc', 'val_loss', 'val_acc', 'param_norm', 'grad_norm', 'param_norm_layer', 'grad_norm_layer', 'g2w_ratio', 'loss_path', 'acc_path', 'dur_total_core', 'dur_train_core', 'dur_dl_train']
# shape: (252, 42)
# ┌──────────────┬────────┬───────────────────────────┬────────────────┬──────────────┬─────────────┬───────────────────────────┬───────────────────────────┬─────────────┬───────────┬────────┬────────┬──────────┬────────────┬─────────────┬───────┬──────────────┬─────────────────┬──────┬───────────┬───────────┬────────────┬──────────────────┬───────────┬───────────────────┬────────────────┬────────────────┬───────────────────────────┬───────────────────────────┬───────────────────────────┬───────────────────────────┬──────────────────────────┬───────────────────────────┬───────────────────────────┬───────────────────────────┬───────────────────────────┬───────────────────────────┬─────────────────┬─────────────────┬───────────────────────────┬───────────────────────────┬───────────────────────────┐
# │ exp_name     ┆ run_id ┆ model_arc                 ┆ train_dataset  ┆ val_dataset  ┆ num_classes ┆ train_trans               ┆ val_trans                 ┆ train_ndata ┆ val_ndata ┆ epochs ┆ max_lr ┆       wd ┆ batch_size ┆ iters/epoch ┆ iters ┆ target_steps ┆ ndata_per_class ┆ fils ┆ ensembles ┆ base_fils ┆ num_params ┆ criterion        ┆ optimizer ┆ scheduler         ┆ step           ┆ epoch          ┆ lr                        ┆ train_loss                ┆ train_acc                 ┆ val_loss                  ┆ val_acc                  ┆ param_norm                ┆ grad_norm                 ┆ param_norm_layer          ┆ grad_norm_layer           ┆ g2w_ratio                 ┆ loss_path       ┆ acc_path        ┆ dur_total_core            ┆ dur_train_core            ┆ dur_dl_train              │
# │ ---          ┆    --- ┆ ---                       ┆ ---            ┆ ---          ┆         --- ┆ ---                       ┆ ---                       ┆         --- ┆       --- ┆    --- ┆    --- ┆      --- ┆        --- ┆         --- ┆   --- ┆          --- ┆             --- ┆  --- ┆       --- ┆       --- ┆        --- ┆ ---              ┆ ---       ┆ ---               ┆ ---            ┆ ---            ┆ ---                       ┆ ---                       ┆ ---                       ┆ ---                       ┆ ---                      ┆ ---                       ┆ ---                       ┆ ---                       ┆ ---                       ┆ ---                       ┆ ---             ┆ ---             ┆ ---                       ┆ ---                       ┆ ---                       │
# │ str          ┆    i64 ┆ str                       ┆ str            ┆ str          ┆         i64 ┆ str                       ┆ str                       ┆         i64 ┆       i64 ┆    i64 ┆    f64 ┆      f64 ┆        i64 ┆         i64 ┆   i64 ┆          i64 ┆             f64 ┆  i64 ┆       i64 ┆       i64 ┆        i64 ┆ str              ┆ str       ┆ str               ┆ list[i64]      ┆ list[i64]      ┆ list[f64]                 ┆ list[f64]                 ┆ list[f64]                 ┆ list[f64]                 ┆ list[f64]                ┆ list[f64]                 ┆ list[f64]                 ┆ list[struct[62]]          ┆ list[struct[62]]          ┆ list[f64]                 ┆ list[list[f64]] ┆ list[list[f64]] ┆ list[f64]                 ┆ list[f64]                 ┆ list[f64]                 │
# ╞══════════════╪════════╪═══════════════════════════╪════════════════╪══════════════╪═════════════╪═══════════════════════════╪═══════════════════════════╪═════════════╪═══════════╪════════╪════════╪══════════╪════════════╪═════════════╪═══════╪══════════════╪═════════════════╪══════╪═══════════╪═══════════╪════════════╪══════════════════╪═══════════╪═══════════════════╪════════════════╪════════════════╪═══════════════════════════╪═══════════════════════════╪═══════════════════════════╪═══════════════════════════╪══════════════════════════╪═══════════════════════════╪═══════════════════════════╪═══════════════════════════╪═══════════════════════════╪═══════════════════════════╪═════════════════╪═════════════════╪═══════════════════════════╪═══════════════════════════╪═══════════════════════════╡
# │ exp_opt      ┆      0 ┆ ee_tools.models.resnet_g… ┆ cifar100_train ┆ cifar100_val ┆         100 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆       10000 ┆     10000 ┆    200 ┆    0.1 ┆    0.003 ┆        128 ┆          79 ┆ 15800 ┆      2000000 ┆           100.0 ┆   64 ┆         1 ┆        64 ┆   11220132 ┆ CrossEntropyLoss ┆ SGD       ┆ CosineAnnealingLR ┆ [1, 2, … 200]  ┆ [1, 2, … 200]  ┆ [0.1, 0.099994, … 0.0000… ┆ [4.412952, 3.915954, … 0… ┆ [0.0482, 0.0867, … 0.999… ┆ [null, 4.041228, … 1.754… ┆ [null, 0.0724, … 0.5904] ┆ [101.96273, 80.656737, …… ┆ [2.043378, 1.330684, … 1… ┆ [{3.697158,7.276463,0.16… ┆ [{0.288584,0.032949,0.02… ┆ [0.019641, 0.016612, … 0… ┆ null            ┆ null            ┆ [3.1892, 5.319546, … 396… ┆ [3.189377, 5.029107, … 3… ┆ [0.066926, 0.13655, … 13… │
# │ exp_opt      ┆      1 ┆ ee_tools.models.resnet_g… ┆ cifar100_train ┆ cifar100_val ┆         100 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆       10000 ┆     10000 ┆    200 ┆    0.1 ┆    0.003 ┆        128 ┆          79 ┆ 15800 ┆      2000000 ┆           100.0 ┆   16 ┆        16 ┆        64 ┆   11409216 ┆ CrossEntropyLoss ┆ SGD       ┆ CosineAnnealingLR ┆ [1, 2, … 200]  ┆ [1, 2, … 200]  ┆ [0.1, 0.099994, … 0.0000… ┆ [4.483505, 4.239091, … 3… ┆ [0.03, 0.0667, … 0.2088]  ┆ [null, 4.365785, … 3.499… ┆ [null, 0.0481, … 0.1858] ┆ [204.116164, 160.700341,… ┆ [0.419628, 0.441169, … 2… ┆ [{8.89473,14.525507,0.07… ┆ [{0.162078,0.013942,0.01… ┆ [0.002052, 0.002774, … 0… ┆ null            ┆ null            ┆ [5.16227, 11.367722, … 1… ┆ [5.162441, 10.067055, … … ┆ [0.066926, 0.13655, … 13… │
# │ exp_opt      ┆      2 ┆ ee_tools.models.resnet_g… ┆ cifar100_train ┆ cifar100_val ┆         100 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆       10000 ┆     10000 ┆    200 ┆    0.1 ┆    0.003 ┆        128 ┆          79 ┆ 15800 ┆      2000000 ┆           100.0 ┆    8 ┆        64 ┆        64 ┆   11664128 ┆ CrossEntropyLoss ┆ SGD       ┆ CosineAnnealingLR ┆ [1, 2, … 200]  ┆ [1, 2, … 200]  ┆ [0.1, 0.099994, … 0.0000… ┆ [4.593002, 4.548108, … 4… ┆ [0.0217, 0.0429, … 0.01]  ┆ [null, 4.564884, … 4.605… ┆ [null, 0.0428, … 0.01]   ┆ [290.5511, 228.575706, …… ┆ [0.164309, 0.123004, … 0… ┆ [{17.863414,20.540505,0.… ┆ [{0.0773,0.008201,0.0081… ┆ [0.000565, 0.000538, … 0… ┆ null            ┆ null            ┆ [11.226474, 25.263264, …… ┆ [11.226661, 21.952506, …… ┆ [0.066926, 0.13655, … 13… │
# │ exp_opt      ┆      3 ┆ ee_tools.models.resnet_g… ┆ cifar100_train ┆ cifar100_val ┆         100 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆       10000 ┆     10000 ┆    200 ┆    0.1 ┆    0.003 ┆        128 ┆          79 ┆ 15800 ┆      2000000 ┆           100.0 ┆    4 ┆       256 ┆        64 ┆   12183552 ┆ CrossEntropyLoss ┆ SGD       ┆ CosineAnnealingLR ┆ [1, 2, … 200]  ┆ [1, 2, … 200]  ┆ [0.1, 0.099994, … 0.0000… ┆ [4.604219, 4.601684, … 4… ┆ [0.0134, 0.0205, … 0.01]  ┆ [null, 4.603734, … 4.605… ┆ [null, 0.0149, … 0.01]   ┆ [415.946435, 327.194858,… ┆ [0.061025, 0.047845, … 0… ┆ [{35.544859,29.048969,0.… ┆ [{0.030074,0.003869,0.00… ┆ [0.000147, 0.000146, … 0… ┆ null            ┆ null            ┆ [37.151627, 81.318986, …… ┆ [37.151813, 72.767807, …… ┆ [0.066926, 0.13655, … 13… │
# │ exp_opt      ┆      4 ┆ ee_tools.models.resnet_g… ┆ cifar100_train ┆ cifar100_val ┆         100 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆       10000 ┆     10000 ┆    200 ┆    0.1 ┆    0.001 ┆        128 ┆          79 ┆ 15800 ┆      2000000 ┆           100.0 ┆   64 ┆         1 ┆        64 ┆   11220132 ┆ CrossEntropyLoss ┆ SGD       ┆ CosineAnnealingLR ┆ [1, 2, … 200]  ┆ [1, 2, … 200]  ┆ [0.1, 0.099994, … 0.0000… ┆ [4.467508, 3.962184, … 0… ┆ [0.0434, 0.0779, … 0.999… ┆ [null, 4.192157, … 1.789… ┆ [null, 0.0654, … 0.575]  ┆ [108.726743, 100.865556,… ┆ [1.72552, 1.182769, … 0.… ┆ [{4.07076,7.75086,0.1916… ┆ [{0.322743,0.034822,0.03… ┆ [0.015751, 0.011729, … 0… ┆ null            ┆ null            ┆ [1.877035, 4.013081, … 3… ┆ [1.877198, 3.723323, … 3… ┆ [0.083054, 0.153258, … 1… │
# │ …            ┆      … ┆ …                         ┆ …              ┆ …            ┆           … ┆ …                         ┆ …                         ┆           … ┆         … ┆      … ┆      … ┆        … ┆          … ┆           … ┆     … ┆            … ┆               … ┆    … ┆         … ┆         … ┆          … ┆ …                ┆ …         ┆ …                 ┆ …              ┆ …              ┆ …                         ┆ …                         ┆ …                         ┆ …                         ┆ …                        ┆ …                         ┆ …                         ┆ …                         ┆ …                         ┆ …                         ┆ …               ┆ …               ┆ …                         ┆ …                         ┆ …                         │
# │ exp_opt_4090 ┆    103 ┆ ee_tools.models.resnet_g… ┆ cifar100_train ┆ cifar100_val ┆         100 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆         500 ┆     10000 ┆   4000 ┆  0.005 ┆  0.00001 ┆        128 ┆           4 ┆ 16000 ┆      2000000 ┆             5.0 ┆    2 ┆      1024 ┆        64 ┆   13260800 ┆ CrossEntropyLoss ┆ AdamW     ┆ CosineAnnealingLR ┆ [1, 2, … 4000] ┆ [1, 2, … 4000] ┆ [0.005, 0.005, … 7.7106e… ┆ [4.621583, 4.569277, … 0… ┆ [0.008, 0.034, … 1.0]     ┆ [null, null, … 7.634691]  ┆ [null, null, … 0.1454]   ┆ [665.365187, 666.63039, … ┆ [0.025313, 0.025191, … 0… ┆ [{78.480155,45.257066,0.… ┆ [{0.012432,0.001903,0.00… ┆ [0.000038, 0.000038, … 7… ┆ null            ┆ null            ┆ [1.741917, 3.480397, … 8… ┆ [1.741922, 3.48041, … 69… ┆ [0.041401, 0.083503, … 1… │
# │ exp_opt_4090 ┆    104 ┆ ee_tools.models.resnet_g… ┆ cifar100_train ┆ cifar100_val ┆         100 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆         500 ┆     10000 ┆   4000 ┆  0.005 ┆ 0.000001 ┆        128 ┆           4 ┆ 16000 ┆      2000000 ┆             5.0 ┆   32 ┆         4 ┆        64 ┆   11282960 ┆ CrossEntropyLoss ┆ AdamW     ┆ CosineAnnealingLR ┆ [1, 2, … 4000] ┆ [1, 2, … 4000] ┆ [0.005, 0.005, … 7.7106e… ┆ [5.02388, 4.752704, … 0.… ┆ [0.008, 0.012, … 1.0]     ┆ [null, null, … 19.657925… ┆ [null, null, … 0.0873]   ┆ [161.304689, 167.092122,… ┆ [1.5792, 1.316162, … 0.0… ┆ [{4.93108,11.305917,0.08… ┆ [{0.78528,0.043143,0.034… ┆ [0.009789, 0.007881, … 4… ┆ null            ┆ null            ┆ [0.165644, 0.332117, … 7… ┆ [0.165649, 0.332127, … 6… ┆ [0.042879, 0.081938, … 1… │
# │ exp_opt_4090 ┆    105 ┆ ee_tools.models.resnet_g… ┆ cifar100_train ┆ cifar100_val ┆         100 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆         500 ┆     10000 ┆   4000 ┆  0.005 ┆ 0.000001 ┆        128 ┆           4 ┆ 16000 ┆      2000000 ┆             5.0 ┆    2 ┆      1024 ┆        64 ┆   13260800 ┆ CrossEntropyLoss ┆ AdamW     ┆ CosineAnnealingLR ┆ [1, 2, … 4000] ┆ [1, 2, … 4000] ┆ [0.005, 0.005, … 7.7106e… ┆ [4.624578, 4.572032, … 0… ┆ [0.014, 0.042, … 1.0]     ┆ [null, null, … 6.823844]  ┆ [null, null, … 0.1456]   ┆ [665.411079, 666.686976,… ┆ [0.025289, 0.024539, … 0… ┆ [{78.642449,45.24788,0.3… ┆ [{0.012323,0.001922,0.00… ┆ [0.000038, 0.000037, … 1… ┆ null            ┆ null            ┆ [1.738586, 3.482786, … 8… ┆ [1.738591, 3.482797, … 6… ┆ [0.042879, 0.081938, … 1… │
# │ exp_opt_4090 ┆    106 ┆ ee_tools.models.resnet_g… ┆ cifar100_train ┆ cifar100_val ┆         100 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆         500 ┆     10000 ┆   4000 ┆  0.005 ┆      0.0 ┆        128 ┆           4 ┆ 16000 ┆      2000000 ┆             5.0 ┆   32 ┆         4 ┆        64 ┆   11282960 ┆ CrossEntropyLoss ┆ AdamW     ┆ CosineAnnealingLR ┆ [1, 2, … 4000] ┆ [1, 2, … 4000] ┆ [0.005, 0.005, … 7.7106e… ┆ [5.010425, 4.49596, … 0.… ┆ [0.004, 0.028, … 1.0]     ┆ [null, null, … 19.973801… ┆ [null, null, … 0.0898]   ┆ [161.241048, 167.040747,… ┆ [1.358334, 0.931692, … 0… ┆ [{4.92125,11.311829,0.09… ┆ [{0.488088,0.031539,0.02… ┆ [0.008433, 0.005575, … 4… ┆ null            ┆ null            ┆ [0.166414, 0.331925, … 7… ┆ [0.166419, 0.331935, … 6… ┆ [0.056234, 0.097161, … 1… │
# │ exp_opt_4090 ┆    107 ┆ ee_tools.models.resnet_g… ┆ cifar100_train ┆ cifar100_val ┆         100 ┆ [ToImage(), RandomCrop(s… ┆ [ToImage(), ToDtype(scal… ┆         500 ┆     10000 ┆   4000 ┆  0.005 ┆      0.0 ┆        128 ┆           4 ┆ 16000 ┆      2000000 ┆             5.0 ┆    2 ┆      1024 ┆        64 ┆   13260800 ┆ CrossEntropyLoss ┆ AdamW     ┆ CosineAnnealingLR ┆ [1, 2, … 4000] ┆ [1, 2, … 4000] ┆ [0.005, 0.005, … 7.7106e… ┆ [4.626214, 4.570451, … 0… ┆ [0.016, 0.038, … 1.0]     ┆ [null, null, … 7.170188]  ┆ [null, null, … 0.1441]   ┆ [665.344613, 666.581638,… ┆ [0.025178, 0.024431, … 0… ┆ [{77.933579,45.258731,0.… ┆ [{0.012308,0.001849,0.00… ┆ [0.000038, 0.000037, … 3… ┆ null            ┆ null            ┆ [1.739442, 3.480951, … 8… ┆ [1.739447, 3.480964, … 6… ┆ [0.056234, 0.097161, … 1… │
# └──────────────┴────────┴───────────────────────────┴────────────────┴──────────────┴─────────────┴───────────────────────────┴───────────────────────────┴─────────────┴───────────┴────────┴────────┴──────────┴────────────┴─────────────┴───────┴──────────────┴─────────────────┴──────┴───────────┴───────────┴────────────┴──────────────────┴───────────┴───────────────────┴────────────────┴────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┴──────────────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┴─────────────────┴─────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┘

# %%
df_b = df_base

# df_b = df_b.filter(pl.col("optimizer") == "SGD")
df_b = df_b.filter(pl.col("optimizer") == "AdamW")
df_b = df_b.filter(pl.col("train_ndata") == 2000)
df_b = df_b.filter(pl.col("base_fils").is_in([64]))

df_s = df_b.pipe(pl_utils.get_stats)

# %%
piv_values = ["train_acc", "val_acc", "train_loss", "val_loss"]
piv_index = ("fils", "ensembles")      # 縦軸
piv_on = "wd"                        # 横軸
ext_column = "train_ndata"           # このカラムの要素ごとにheatmapを表示
agg = "first"
axis = None    # None: 正規化なし, 0: 行方向, 1: 列方向

# %%
df_e = df_b
ext_l = df_e[ext_column].unique()
for i, ext in enumerate(ext_l):
    piv_values = piv_values if isinstance(piv_values, list) else [piv_values]

    fig, ax = None, None

    for piv_value in piv_values:
        df_ext = df_e.filter(pl.col(ext_column) == ext)
        df_piv = df_ext.pivot(values=piv_value, index=piv_index, on=piv_on, sort_columns=True, aggregate_function=agg)

        # カラムが文字列順になっているため、数字部分をソート
        new_columns = pl.DataFrame({"cols": df_piv.columns}).with_columns(pl.col("cols").cast(pl.Float32, strict=False).alias("numeric")).sort("numeric", maintain_order=True)["cols"].to_list()
        df_piv = df_piv.select(new_columns)

        # (fil, ensemble) の形式に
        df_piv = df_piv.with_columns(("(" + pl.col("fils").cast(pl.String) + "," + pl.col("ensembles").cast(pl.String)).alias("(fils, ensembles)") + ")").sort("fils", descending=True)
        df_piv = df_piv.select(["(fils, ensembles)"] + new_columns).select(pl.exclude(["fils", "ensembles"]))

        # 0列目がx軸ラベル、1列目以降がy軸ラベルになる df_s を heat map に変換
        ax_x = df_piv.columns[1:]
        ax_y = df_piv[df_piv.columns[0]]
        data = df_piv.select(ax_x).to_numpy()
        
        if np.issubdtype(data.dtype, np.number):
            # 数値データ
            annot = data.copy()

            if axis:
                # min-max 正規化
                # min_vals = data.min(axis=axis, keepdims=True)
                # max_vals = data.max(axis=axis, keepdims=True)
                # data = (data - min_vals) / (max_vals - min_vals + 1e-8)  # ゼロ除算対策
                
                # Zスコア正規化
                mean_vals = data.mean(axis=axis, keepdims=True)
                std_vals = data.std(axis=axis, keepdims=True)
                data = (data - mean_vals) / (std_vals + 1e-8)  # ゼロ除算対策

            if piv_value[-4:] == "_acc":
                annot *= 100
                
            square_size = 0.75

            fig, ax = plt.subplots(figsize=(len(ax_x)*square_size, len(ax_y)*square_size))
            fontname, fontweight = "Lato", 300

            hm_kwargs = {
                "cmap": "Blues_r",
                "cbar": False,
                # "cbar_kws": {"ticks": []},
                "fmt": ".2f",
                "annot_kws": {"size": 11, "fontname": fontname, "fontweight": 500}
            }

            ax = sns.heatmap(data, annot=annot, square=False, **hm_kwargs)
            ax.set_title(f"{ext_column}: {ext}", fontsize=14, fontname=fontname, fontweight=fontweight)
            ax.set_xlabel(piv_on, fontsize=12, fontname=fontname, fontweight=fontweight)
            ax.set_ylabel(ax_y.name, fontsize=12, rotation=90, fontname=fontname, fontweight=fontweight)

            ax.set_xticklabels(ax_x, fontsize=11, rotation=0)
            for label in ax.get_xticklabels():
                label.set_fontname(fontname)
                label.set_fontweight(fontweight)

            ax.set_yticklabels(ax_y, fontsize=11, rotation=0)
            for label in ax.get_yticklabels():
                label.set_fontname(fontname)
                label.set_fontweight(fontweight)
            plt.show()
        
        else:
            # 配列データ
            df_step = df_ext.pivot(values="step", index=piv_index, on=piv_on, sort_columns=True, aggregate_function=agg)

            # カラムが文字列順になっているため、数字部分をソート
            new_columns = pl.DataFrame({"cols": df_step.columns}).with_columns(pl.col("cols").cast(pl.Float32, strict=False).alias("numeric")).sort("numeric", maintain_order=True)["cols"].to_list()
            df_step = df_step.select(new_columns)

            # (fil, ensemble) の形式に
            df_step = df_step.with_columns(("(" + pl.col("fils").cast(pl.String) + "," + pl.col("ensembles").cast(pl.String)).alias("(fils, ensembles)") + ")").sort("fils", descending=True)
            df_step = df_step.select(["(fils, ensembles)"] + new_columns).select(pl.exclude(["fils", "ensembles"]))

            _ax_x = df_step.columns[1:]
            # _ax_y = df_step[df_step.columns[0]]
            step_data = df_step.select(_ax_x).to_numpy()
            
            nrows, ncols = data.shape
            if fig is None:
                fig, axes = plt.subplots(nrows, ncols, figsize=(ncols * 4, nrows * 3), sharex=False, sharey=False, squeeze=False)
                modern_colors = ['#368DFF', '#FF6495', '#3DD598', '#FFC542', '#8C52FF', '#FF6E4A']
                plt.rcParams['axes.prop_cycle'] = cycler(color=modern_colors)
            
            fontname, fontweight = "Lato", 300

            # 全体のタイトルを設定
            fig.suptitle(f"{ext_column}: {ext}", fontsize=16, fontname=fontname, fontweight=fontweight)

            # 各サブプロットに折れ線グラフを描画
            for i in range(nrows):
                for j in range(ncols):
                    ax = axes[i, j]
                    
                    # 対応するX軸とY軸のデータを取得
                    x_data = step_data[i, j]
                    y_data = data[i, j]
                    
                    # データが存在することを確認
                    if x_data is not None and y_data is not None:
                        filtered_points = [
                            (x, y) for x, y in zip(x_data, y_data) 
                            if y is not None and not np.isnan(y)
                        ]
                        
                        # 有効なデータが1点以上残っている場合のみプロット
                        if len(filtered_points) > 1: # 線を描画するには点が2つ以上必要
                            
                            # X軸の値でソート
                            sorted_points = sorted(filtered_points, key=lambda point: point[0])
                            
                            # ソートされたリストからxとyを再作成
                            x_plot, y_plot = zip(*sorted_points)
                            
                            # 最終的なプロット
                            ax.plot(x_plot, y_plot, linewidth=1.5, label=piv_value)

                    # ティックのフォントを設定
                    ax.tick_params(axis='both', which='major', labelsize=8)
                    for label in ax.get_xticklabels() + ax.get_yticklabels():
                        label.set_fontname(fontname) 

                    legend = ax.legend(fontsize=11, frameon=False)

                    fig.patch.set_facecolor('#F4F7FC')
                    ax.set_facecolor('#EEEEEE')

                    ax.set_ylim([0, 1])
                    # ax.set_xlabel(x_col, fontsize=14, color='#333333')
                    # ax.set_ylabel("Accuracy", fontsize=14, color='#333333')
                    ax.grid(axis='y', linestyle='-', color='#FFFFFF', alpha=0.5, linewidth=1.2) # グリッドを薄い白ベースで太く

                    ax.tick_params(axis='both', which='major', labelsize=11, colors='#333333')
                    ax.tick_params(axis='both', which='both', length=0)

                    ax.spines['top'].set_visible(False)
                    ax.spines['right'].set_visible(False)
                    ax.spines['left'].set_visible(False)
                    ax.spines['bottom'].set_visible(False)
                
            # Y軸の行ラベル (グリッドの左端に表示)
            for i, row_label in enumerate(ax_y):
                # rotation=0で横書きにし、位置を調整
                axes[i, 0].set_ylabel(row_label, rotation=0, ha='right', va='center', fontsize=10, fontname=fontname, fontweight=fontweight)

            # X軸の列ラベル (グリッドの下端に表示)
            for j, col_label in enumerate(ax_x):
                axes[-1, j].set_xlabel(col_label, fontsize=10, fontname=fontname, fontweight=fontweight)
                
            # 全体の共通軸ラベル
            fig.text(0.5, 0.01, piv_on, ha='center', va='center', fontsize=12, fontname=fontname, fontweight=fontweight)
            fig.text(0.02, 0.5, ax_y.name, ha='center', va='center', rotation='vertical', fontsize=12, fontname=fontname, fontweight=fontweight)
            
            # レイアウトを調整してラベルが重ならないようにする
            fig.subplots_adjust(left=0.07, right=0.92, bottom=0.05, top=0.95)
        
    plt.show()
